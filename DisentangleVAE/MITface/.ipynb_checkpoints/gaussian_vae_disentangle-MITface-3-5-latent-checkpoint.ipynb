# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from keras.layers import Lambda, Input, Dense
from keras.models import Model
from keras.datasets import mnist
from keras.losses import mse, binary_crossentropy
from keras.utils import plot_model
from keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import argparse
import os
# Out:
# Using TensorFlow backend.

# %%
from os import listdir
from os.path import isfile, join
mypath= 'training-synthetic/'
files = [join(mypath, f) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
import re
import numpy

def read_pgm(filename, byteorder='>'):
    """Return image data from a raw PGM file as numpy array.

    Format specification: http://netpbm.sourceforge.net/doc/pgm.html

    """
    with open(filename, 'rb') as f:
        buffer = f.read()
    try:
        header, width, height, maxval = re.search(
            b"(^P5\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n]\s)*)", buffer).groups()
    except AttributeError:
        raise ValueError("Not a raw PGM file: '%s'" % filename)
    return numpy.frombuffer(buffer,
                            dtype='u1' if int(maxval) < 256 else byteorder+'u2',
                            count=int(width)*int(height),
                            offset=len(header)
                            ).reshape((int(height), int(width)))

# %%
face=[]
import math
for file in files:     
    f=read_pgm(file)
    face.append(f)
    
face =np.asarray(face)
num_face = face.shape[0]
num_train = math.ceil(num_face *0.9)
#num_train = 180
img_rows = face.shape[1]
img_cols = face.shape[2]
ff= face

# %%
face.shape
# Out:
# (3240, 200, 200)

# %%
# split data into train / validation folds
np.random.seed(42)
n_pixels = img_rows * img_cols
x_train = ff[:num_train]
x_test = ff[num_train:num_face]

# %%
x_train.shape
# Out:
# (2916, 200, 200)

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), n_pixels))
x_test = x_test.reshape((len(x_test), n_pixels))

# %%
def show_examples(data, n=None, n_cols=20, thumbnail_cb=None):
    if n is None:
        n = len(data)    
    n_rows = int(np.ceil(n / float(n_cols)))
    figure = np.zeros((img_rows * n_rows, img_cols * n_cols))
    for k, x in enumerate(data[:n]):
        r = k // n_cols
        c = k % n_cols
        figure[r * img_rows: (r + 1) * img_rows,
               c * img_cols: (c + 1) * img_cols] = x
        if thumbnail_cb is not None:
            thumbnail_cb(locals())
        
    plt.figure(figsize=(12, 10))
    plt.imshow(figure)
    plt.axis("off")
    plt.tight_layout()
show_examples(ff, n=500, n_cols=25)

# %%
import tensorflow as tf
sess = tf.Session()

K.set_session(sess)

# %%
def sampling(args):
    """Reparameterization trick by sampling fr an isotropic unit Gaussian.

    # Arguments:
        args (tensor): mean and log of variance of Q(z|X)

    # Returns:
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon
#     return z_mean + K.exp(0.5 ) * epsilon

# %%
def plot_results(models,
                 latent_dim,
                 latent_num,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):
    """Plots labels and MNIST digits as function of 2-dim latent vector

    # Arguments:
        models (tuple): encoder and decoder models
        data (tuple): test data and label
        batch_size (int): prediction batch size
        model_name (string): which model is using this function
    """

    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)

    
    
    """filename = os.path.join(model_name, "vae_mean.png")
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = encoder.predict(x_test,
                                   batch_size=batch_size)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=y_test)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.savefig(filename)
    plt.show()
    """

    #filename = os.path.join(model_name, "face_over_latent.png")
    n = 20
    digit_size = 200
    img_rows, img_cols = 200, 200
    figure = np.zeros((img_rows , img_cols * n))
    grid_x = np.linspace(-5, 5, n)
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
    z_sample[0,:] = z_m_m 
    
    for j, xi in enumerate(grid_x):
        z_sample[0,latent_num] = z_m_m[latent_num] + xi
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(img_rows, img_cols)
        figure[0: img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    #plt.savefig(filename)
    plt.show()

# %%
from random import *
def plot_random_results(models,
                 latent_dim,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):


    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "face_over_latent.png")
    n = 10
    digit_size = 28
    img_rows, img_cols = 28, 20
    figure = np.zeros((img_rows * n , img_cols * n))
    
    #grid_x = np.linspace(-5, 5, n)
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
     
    
    for j in range(n):
        for k in range(n):
            z_sample[0,:] = z_m_m
            l = [x * 2 for x in [uniform(-1,1) for i in range(latent_dim)]]
            z_sample[0,:] += l
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(img_rows, img_cols)
            figure[k * img_rows : (k+1) * img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    plt.savefig(filename)
    plt.show()

# %%
[uniform(-1,1) for i in range(5)]
# Out:
# [-0.431550666261711,
#  0.7329197455624623,
#  -0.31716977564972826,
#  0.4762250293842012,
#  0.8039367362757164]

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 3
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
# standardize the mean of z, so that mean(m_z)=0 and cov(m_z)=I
def standardize(z_mean):
    z_m_m = K.mean(z_mean,axis=0, keepdims=True)
    z1 = z_mean - z_m_m
    n = tf.cast(K.shape(z_mean)[0], tf.float32)
    cov = K.transpose(z1) @ z1 /n
    
    D = tf.diag(tf.diag_part(cov)) ** 0.5
    
    L = tf.linalg.inv(tf.transpose(tf.cholesky(cov)))
       
#     z2 = z1 @ L @ D +  z_m_m
    z2 = z1 @ L  +  z_m_m
    return( z2)

z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 40000)        0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          8000200     encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 3)            603         dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 3)            603         dense_1[0][0]
# __________________________________________________________________________________________________
# z_mean_std (Lambda)             (None, 3)            0           z_mean[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 3)            0           z_mean_std[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 8,001,406
# Trainable params: 8,001,406
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               800
# _________________________________________________________________
# dense_3 (Dense)              (None, 40000)             8040000
# =================================================================
# Total params: 8,040,800
# Trainable params: 8,040,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 40000)             0
# _________________________________________________________________
# encoder (Model)              [(None, 3), (None, 3), (N 8001406
# _________________________________________________________________
# decoder (Model)              (None, 40000)             8040800
# =================================================================
# Total params: 16,042,206
# Trainable params: 16,042,206
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 2916 samples, validate on 324 samples
# Epoch 1/100
# 2916/2916 [==============================] - 2s 747us/step - loss: 20987.6403 - val_loss: 19621.3664
# Epoch 2/100
# 2916/2916 [==============================] - 1s 258us/step - loss: 19545.2182 - val_loss: 19420.5106
# Epoch 3/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19449.4016 - val_loss: 19332.2163
# Epoch 4/100
# 2916/2916 [==============================] - 1s 256us/step - loss: 19357.0044 - val_loss: 19297.2652
# Epoch 5/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19310.1820 - val_loss: 19243.4619
# Epoch 6/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19298.7346 - val_loss: 19236.4514
# Epoch 7/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19230.5318 - val_loss: 19194.4925
# Epoch 8/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19244.6908 - val_loss: 19243.9025
# Epoch 9/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19233.0732 - val_loss: 19162.2989
# Epoch 10/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19204.7371 - val_loss: 19167.5358
# Epoch 11/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19185.6901 - val_loss: 19181.1794
# Epoch 12/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19185.1119 - val_loss: 19147.5599
# Epoch 13/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 19179.6835 - val_loss: 19120.5241
# Epoch 14/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19190.4775 - val_loss: 19129.8797
# Epoch 15/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19174.8629 - val_loss: 19136.7507
# Epoch 16/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19167.8816 - val_loss: 19118.8014
# Epoch 17/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19173.0036 - val_loss: 19143.5595
# Epoch 18/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19165.2465 - val_loss: 19124.5246
# Epoch 19/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19146.4218 - val_loss: 19109.0046
# Epoch 20/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19149.2932 - val_loss: 19109.3093
# Epoch 21/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19165.6745 - val_loss: 19103.0112
# Epoch 22/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19159.5680 - val_loss: 19091.7792
# Epoch 23/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19145.6423 - val_loss: 19089.6410
# Epoch 24/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19134.6921 - val_loss: 19101.5438
# Epoch 25/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19133.0546 - val_loss: 19106.0564
# Epoch 26/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19121.5207 - val_loss: 19071.1631
# Epoch 27/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 19109.6013 - val_loss: 19079.8537
# Epoch 28/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 
100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18807.1344 - val_loss: 18763.8951
# Epoch 84/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18804.8492 - val_loss: 18747.2969
# Epoch 85/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18788.4936 - val_loss: 18750.3945
# Epoch 86/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18803.7400 - val_loss: 18759.4847
# Epoch 87/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18795.1571 - val_loss: 18757.2526
# Epoch 88/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18802.4975 - val_loss: 18748.4334
# Epoch 89/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18785.8632 - val_loss: 18758.2502
# Epoch 90/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18794.2975 - val_loss: 18740.8589
# Epoch 91/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18782.5796 - val_loss: 18760.1157
# Epoch 92/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18787.6539 - val_loss: 18746.7357
# Epoch 93/100
# 2916/2916 [==============================] - 1s 259us/step - loss: 18777.2853 - val_loss: 18738.5901
# Epoch 94/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18796.8614 - val_loss: 18744.7154
# Epoch 95/100
# 2916/2916 [==============================] - 1s 256us/step - loss: 18787.0922 - val_loss: 18743.2311
# Epoch 96/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18779.6725 - val_loss: 18734.8517
# Epoch 97/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18776.6067 - val_loss: 18728.2797
# Epoch 98/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18775.9198 - val_loss: 18735.3826
# Epoch 99/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18780.0867 - val_loss: 18730.6332
# Epoch 100/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18778.2233 - val_loss: 18783.7128

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input:0':x_test})

z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
np.zeros((1, 2 )) 
print(z_m_m)

np.cov(z_output.T)
# Out:
# [1.360624  0.7199342 0.5021543]
# array([[ 1.00309587e+00,  1.59027467e-08, -3.64235110e-08],
#        [ 1.59027467e-08,  1.00309616e+00, -7.80258070e-08],
#        [-3.64235110e-08, -7.80258070e-08,  1.00309623e+00]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")

# %%
'''
plot_random_results(models,
                 latent_dim,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
'''
# Out:
# '\nplot_random_results(models,\n                 latent_dim,\n                 z_m_m = z_m_m ,\n                 batch_size=batch_size,\n                 model_name="vae_mlp")\n'

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 4
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input_1')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
# standardize the mean of z, so that mean(m_z)=0 and cov(m_z)=I
def standardize(z_mean):
    z_m_m = K.mean(z_mean,axis=0, keepdims=True)
    z1 = z_mean - z_m_m
    n = tf.cast(K.shape(z_mean)[0], tf.float32)
    cov = K.transpose(z1) @ z1 /n
    
    D = tf.diag(tf.diag_part(cov)) ** 0.5
    
    L = tf.linalg.inv(tf.transpose(tf.cholesky(cov)))
       
#     z2 = z1 @ L @ D +  z_m_m
    z2 = z1 @ L  +  z_m_m
    return( z2)

z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_1 (InputLayer)    (None, 40000)        0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 200)          8000200     encoder_input_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 4)            804         dense_4[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            804         dense_4[0][0]
# __________________________________________________________________________________________________
# z_mean_std (Lambda)             (None, 4)            0           z_mean[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 4)            0           z_mean_std[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 8,001,808
# Trainable params: 8,001,808
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 4)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 200)               1000
# _________________________________________________________________
# dense_6 (Dense)              (None, 40000)             8040000
# =================================================================
# Total params: 8,041,000
# Trainable params: 8,041,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input_1 (InputLayer) (None, 40000)             0
# _________________________________________________________________
# encoder (Model)              [(None, 4), (None, 4), (N 8001808
# _________________________________________________________________
# decoder (Model)              (None, 40000)             8041000
# =================================================================
# Total params: 16,042,808
# Trainable params: 16,042,808
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 2916 samples, validate on 324 samples
# Epoch 1/100
# 2916/2916 [==============================] - 2s 541us/step - loss: 21015.6377 - val_loss: 19569.5110
# Epoch 2/100
# 2916/2916 [==============================] - 1s 259us/step - loss: 19547.4091 - val_loss: 19482.6958
# Epoch 3/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19421.7972 - val_loss: 19314.6898
# Epoch 4/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19341.3946 - val_loss: 19341.4878
# Epoch 5/100
# 2916/2916 [==============================] - 1s 255us/step - loss:
100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18785.4695 - val_loss: 18758.7807
# Epoch 61/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18783.4327 - val_loss: 18758.4213
# Epoch 62/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18791.2519 - val_loss: 18775.7660
# Epoch 63/100
# 2916/2916 [==============================] - 1s 258us/step - loss: 18798.8253 - val_loss: 18771.9514
# Epoch 64/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18782.0151 - val_loss: 18738.8092
# Epoch 65/100
# 2916/2916 [==============================] - 1s 259us/step - loss: 18773.7129 - val_loss: 18738.9509
# Epoch 66/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18780.8984 - val_loss: 18758.5761
# Epoch 67/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18776.1829 - val_loss: 18738.6758
# Epoch 68/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18770.2982 - val_loss: 18743.5831
# Epoch 69/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18775.6105 - val_loss: 18727.2622
# Epoch 70/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18768.4663 - val_loss: 18728.7772
# Epoch 71/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18766.6902 - val_loss: 18717.7155
# Epoch 72/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 18764.0792 - val_loss: 18724.0544
# Epoch 73/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18754.2010 - val_loss: 18730.7010
# Epoch 74/100
# 2916/2916 [==============================] - 1s 265us/step - loss: 18754.6639 - val_loss: 18718.2406
# Epoch 75/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18757.4510 - val_loss: 18722.6121
# Epoch 76/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18755.4039 - val_loss: 18720.2415
# Epoch 77/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18752.6766 - val_loss: 18726.0495
# Epoch 78/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18754.8811 - val_loss: 18709.0714
# Epoch 79/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18749.3505 - val_loss: 18707.3655
# Epoch 80/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18748.5338 - val_loss: 18709.0441
# Epoch 81/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18745.4643 - val_loss: 18706.4125
# Epoch 82/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18753.6246 - val_loss: 18730.7045
# Epoch 83/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18745.2539 - val_loss: 18703.7999
# Epoch 84/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18746.3790 - val_loss: 18705.0961
# Epoch 85/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18739.4082 - val_loss: 18715.2013
# Epoch 86/100
# 2916/2916 [==============================] - 1s 258us/step - loss: 18757.9772 - val_loss: 18711.5518
# Epoch 87/100
# 2916/2916 [==============================] - 1s 255us/step - loss: 18741.2607 - val_loss: 18697.7315
# Epoch 88/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18736.8847 - val_loss: 18714.2648
# Epoch 89/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18738.9180 - val_loss: 18698.4005
# Epoch 90/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18736.8263 - val_loss: 18706.3677
# Epoch 91/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18741.1843 - val_loss: 18701.8873
# Epoch 92/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18744.2911 - val_loss: 18702.5704
# Epoch 93/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18745.3621 - val_loss: 18698.1850
# Epoch 94/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18737.3479 - val_loss: 18695.1264
# Epoch 95/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18729.5582 - val_loss: 18693.2053
# Epoch 96/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 18725.8073 - val_loss: 18701.0430
# Epoch 97/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18737.8231 - val_loss: 18684.6874
# Epoch 98/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18725.6807 - val_loss: 18689.3277
# Epoch 99/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18718.2188 - val_loss: 18687.0750
# Epoch 100/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18734.0613 - val_loss: 18692.7216

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input_1:0':x_test})
z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
np.zeros((1, 2 )) 
z_m_m
# Out:
# array([ 0.38725758,  0.32177588, -1.084482  , -1.4651141 ], dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 1.00309579e+00, -5.22786650e-08,  1.81167999e-08,
#          5.41245986e-08],
#        [-5.22786650e-08,  1.00309592e+00, -7.70706948e-09,
#          2.50317237e-08],
#        [ 1.81167999e-08, -7.70706948e-09,  1.00309636e+00,
#          9.63052084e-08],
#        [ 5.41245986e-08,  2.50317237e-08,  9.63052084e-08,
#          1.00309620e+00]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 5
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input_2')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
# standardize the mean of z, so that mean(m_z)=0 and cov(m_z)=I
def standardize(z_mean):
    z_m_m = K.mean(z_mean,axis=0, keepdims=True)
    z1 = z_mean - z_m_m
    n = tf.cast(K.shape(z_mean)[0], tf.float32)
    cov = K.transpose(z1) @ z1 /n
    
    D = tf.diag(tf.diag_part(cov)) ** 0.5
    
    L = tf.linalg.inv(tf.transpose(tf.cholesky(cov)))
       
#     z2 = z1 @ L @ D +  z_m_m
    z2 = z1 @ L  +  z_m_m
    return( z2)

z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_2 (InputLayer)    (None, 40000)        0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 200)          8000200     encoder_input_2[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 5)            1005        dense_7[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 5)            1005        dense_7[0][0]
# __________________________________________________________________________________________________
# z_mean_std (Lambda)             (None, 5)            0           z_mean[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 5)            0           z_mean_std[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 8,002,210
# Trainable params: 8,002,210
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 5)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               1200
# _________________________________________________________________
# dense_9 (Dense)              (None, 40000)             8040000
# =================================================================
# Total params: 8,041,200
# Trainable params: 8,041,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input_2 (InputLayer) (None, 40000)             0
# _________________________________________________________________
# encoder (Model)              [(None, 5), (None, 5), (N 8002210
# _________________________________________________________________
# decoder (Model)              (None, 40000)             8041200
# =================================================================
# Total params: 16,043,410
# Trainable params: 16,043,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 2916 samples, validate on 324 samples
# Epoch 1/100
# 2916/2916 [==============================] - 2s 548us/step - loss: 21227.4220 - val_loss: 19663.9630
# Epoch 2/100
# 2916/2916 [==============================] - 1s 258us/step - loss: 19611.2875 - val_loss: 19468.8438
# Epoch 3/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 19439.8013 - val_loss: 19470.1306
# Epoch 4/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19334.6126 - val_loss: 19274.9130
# Epoch 5/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19249.1032 - val_loss: 19208.7558
# Epoch 6/100
# 2916/2916 [==============================] - 1s 258us/step - loss: 19233.2274 - val_loss: 19289.8422
# Epoch 7/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19161.1026 - val_loss: 19156.8490
# Epoch 8/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19116.7897 - val_loss: 19038.3589
# Epoch 9/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19118.4780 - val_loss: 19108.2914
# Epoch 10/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19061.4203 - val_loss: 19067.9188
# Epoch 11/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 19065.0670 - val_loss: 19083.1116
# Epoch 12/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19045.0380 - val_loss: 19019.1226
# Epoch 13/100
# 2916/2916 [==============================] - 1s 258us/step - loss: 19034.6020 - val_loss: 18984.7035
# Epoch 14/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19031.4089 - val_loss: 19008.6957
# Epoch 15/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 19018.1870 - val_loss: 18965.6611
# Epoch 16/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18990.0474 - val_loss: 19000.8584
# Epoch 17/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19018.0855 - val_loss: 19005.1706
# Epoch 18/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18978.8337 - val_loss: 18969.2523
# Epoch 19/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 18969.3408 - val_loss: 18946.2031
# Epoch 20/100
# 2916/2916 [==============================] - 1s 269us/step - loss: 18969.1046 - val_loss: 18922.2088
# Epoch 21/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18950.5295 - val_loss: 18923.9407
# Epoch 22/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18930.2313 - val_loss: 18900.1849
# Epoch 23/100
# 2916/2916 [==============================] - 1s 265us/step - loss: 
100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18729.4951 - val_loss: 18679.1311
# Epoch 73/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18715.7322 - val_loss: 18677.2894
# Epoch 74/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18719.0632 - val_loss: 18721.0279
# Epoch 75/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18724.9929 - val_loss: 18710.9037
# Epoch 76/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18715.7126 - val_loss: 18708.0232
# Epoch 77/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18703.0090 - val_loss: 18683.4803
# Epoch 78/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18698.9313 - val_loss: 18686.4967
# Epoch 79/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18695.0593 - val_loss: 18661.4414
# Epoch 80/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18701.9593 - val_loss: 18721.4657
# Epoch 81/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18699.0359 - val_loss: 18712.1499
# Epoch 82/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18692.5196 - val_loss: 18651.7603
# Epoch 83/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18694.4781 - val_loss: 18661.7549
# Epoch 84/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 18703.9139 - val_loss: 18665.4471
# Epoch 85/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18705.2144 - val_loss: 18698.3659
# Epoch 86/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18702.5128 - val_loss: 18662.2473
# Epoch 87/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18702.4637 - val_loss: 18701.9837
# Epoch 88/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18703.7821 - val_loss: 18654.8865
# Epoch 89/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18682.7223 - val_loss: 18650.8805
# Epoch 90/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18679.1425 - val_loss: 18654.3077
# Epoch 91/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18684.7682 - val_loss: 18657.7746
# Epoch 92/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18685.8559 - val_loss: 18655.7413
# Epoch 93/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18690.0109 - val_loss: 18691.2178
# Epoch 94/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18689.2192 - val_loss: 18672.1416
# Epoch 95/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 18684.0310 - val_loss: 18717.0433
# Epoch 96/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18700.2719 - val_loss: 18666.2722
# Epoch 97/100
# 2916/2916 [==============================] - 1s 259us/step - loss: 18698.3978 - val_loss: 18661.5460
# Epoch 98/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18681.3939 - val_loss: 18689.7520
# Epoch 99/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18683.8315 - val_loss: 18649.5460
# Epoch 100/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18686.5737 - val_loss: 18673.4583

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input_2:0':x_test})
z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
#np.zeros((1, 2 )) 
z_m_m
# Out:
# array([ 0.29867408, -0.4282988 , -0.23966484,  0.08695056,  2.495489  ],
#       dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 1.00309596e+00, -5.06647472e-09, -4.48871804e-09,
#          6.83370201e-09,  4.37307479e-08],
#        [-5.06647472e-09,  1.00309595e+00,  1.17138685e-08,
#         -2.48622404e-09,  1.08177741e-08],
#        [-4.48871804e-09,  1.17138685e-08,  1.00309602e+00,
#          2.14717672e-09,  1.53100579e-08],
#        [ 6.83370201e-09, -2.48622404e-09,  2.14717672e-09,
#          1.00309583e+00,  7.13468954e-09],
#        [ 4.37307479e-08,  1.08177741e-08,  1.53100579e-08,
#          7.13468954e-09,  1.00309579e+00]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
