# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from keras.layers import Lambda, Input, Dense
from keras.models import Model
from keras.datasets import mnist
from keras.losses import mse, binary_crossentropy
from keras.utils import plot_model
from keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import argparse
import os
# Out:
# Using TensorFlow backend.

# %%
from os import listdir
from os.path import isfile, join
mypath= 'training-synthetic/'
files = [join(mypath, f) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
import re
import numpy

def read_pgm(filename, byteorder='>'):
    """Return image data from a raw PGM file as numpy array.

    Format specification: http://netpbm.sourceforge.net/doc/pgm.html

    """
    with open(filename, 'rb') as f:
        buffer = f.read()
    try:
        header, width, height, maxval = re.search(
            b"(^P5\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n]\s)*)", buffer).groups()
    except AttributeError:
        raise ValueError("Not a raw PGM file: '%s'" % filename)
    return numpy.frombuffer(buffer,
                            dtype='u1' if int(maxval) < 256 else byteorder+'u2',
                            count=int(width)*int(height),
                            offset=len(header)
                            ).reshape((int(height), int(width)))

# %%
face=[]
import math
for file in files:     
    f=read_pgm(file)
    face.append(f)
    
face =np.asarray(face)
num_face = face.shape[0]
num_train = math.ceil(num_face *0.9)
#num_train = 180
img_rows = face.shape[1]
img_cols = face.shape[2]
ff= face

# %%
face.shape
# Out:
# (3240, 200, 200)

# %%
# split data into train / validation folds
np.random.seed(42)
n_pixels = img_rows * img_cols
x_train = ff[:num_train]
x_test = ff[num_train:num_face]

# %%
x_train.shape
# Out:
# (2916, 200, 200)

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), n_pixels))
x_test = x_test.reshape((len(x_test), n_pixels))

# %%
def show_examples(data, n=None, n_cols=20, thumbnail_cb=None):
    if n is None:
        n = len(data)    
    n_rows = int(np.ceil(n / float(n_cols)))
    figure = np.zeros((img_rows * n_rows, img_cols * n_cols))
    for k, x in enumerate(data[:n]):
        r = k // n_cols
        c = k % n_cols
        figure[r * img_rows: (r + 1) * img_rows,
               c * img_cols: (c + 1) * img_cols] = x
        if thumbnail_cb is not None:
            thumbnail_cb(locals())
        
    plt.figure(figsize=(12, 10))
    plt.imshow(figure)
    plt.axis("off")
    plt.tight_layout()
show_examples(ff, n=500, n_cols=25)

# %%
import tensorflow as tf
sess = tf.Session()

K.set_session(sess)

# %%
def sampling(args):
    """Reparameterization trick by sampling fr an isotropic unit Gaussian.

    # Arguments:
        args (tensor): mean and log of variance of Q(z|X)

    # Returns:
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon
#     return z_mean + K.exp(0.5 ) * epsilon

# %%
def plot_results(models,
                 latent_dim,
                 latent_num,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):
    """Plots labels and MNIST digits as function of 2-dim latent vector

    # Arguments:
        models (tuple): encoder and decoder models
        data (tuple): test data and label
        batch_size (int): prediction batch size
        model_name (string): which model is using this function
    """

    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)

    
    
    """filename = os.path.join(model_name, "vae_mean.png")
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = encoder.predict(x_test,
                                   batch_size=batch_size)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=y_test)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.savefig(filename)
    plt.show()
    """

    #filename = os.path.join(model_name, "face_over_latent.png")
    n = 20
    digit_size = 200
    img_rows, img_cols = 200, 200
    figure = np.zeros((img_rows , img_cols * n))
    grid_x = np.linspace(-5, 5, n)
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
    z_sample[0,:] = z_m_m 
    
    for j, xi in enumerate(grid_x):
        z_sample[0,latent_num] = z_m_m[latent_num] + xi
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(img_rows, img_cols)
        figure[0: img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    #plt.savefig(filename)
    plt.show()

# %%
from random import *
def plot_random_results(models,
                 latent_dim,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):


    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "face_over_latent.png")
    n = 10
    digit_size = 28
    img_rows, img_cols = 28, 20
    figure = np.zeros((img_rows * n , img_cols * n))
    
    #grid_x = np.linspace(-5, 5, n)
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
     
    
    for j in range(n):
        for k in range(n):
            z_sample[0,:] = z_m_m
            l = [x * 2 for x in [uniform(-1,1) for i in range(latent_dim)]]
            z_sample[0,:] += l
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(img_rows, img_cols)
            figure[k * img_rows : (k+1) * img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    plt.savefig(filename)
    plt.show()

# %%
[uniform(-1,1) for i in range(5)]
# Out:
# [0.6045676733399792,
#  -0.23197988340049958,
#  -0.633676991644458,
#  0.43053516263275027,
#  0.12253050212230643]

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 3
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 40000)        0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          8000200     encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 3)            603         dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 3)            603         dense_1[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 3)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 8,001,406
# Trainable params: 8,001,406
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               800
# _________________________________________________________________
# dense_3 (Dense)              (None, 40000)             8040000
# =================================================================
# Total params: 8,040,800
# Trainable params: 8,040,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 40000)             0
# _________________________________________________________________
# encoder (Model)              [(None, 3), (None, 3), (N 8001406
# _________________________________________________________________
# decoder (Model)              (None, 40000)             8040800
# =================================================================
# Total params: 16,042,206
# Trainable params: 16,042,206
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 2916 samples, validate on 324 samples
# Epoch 1/100
# 2916/2916 [==============================] - 2s 588us/step - loss: 21057.8244 - val_loss: 19543.1723
# Epoch 2/100
# 2916/2916 [==============================] - 1s 254us/step - loss: 19499.3974 - val_loss: 19346.4456
# Epoch 3/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 19376.6848 - val_loss: 19293.2057
# Epoch 4/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 19281.3804 - val_loss: 19196.9429
# Epoch 5/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19178.1765 - val_loss: 19115.3415
# Epoch 6/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19136.5345 - val_loss: 19086.7604
# Epoch 7/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 19137.3910 - val_loss: 19076.0972
# Epoch 8/100
# 2916/2916 [==============================] - 1s 262us/step - loss: 19094.9421 - val_loss: 19052.9622
# Epoch 9/100
# 2916/2916 [==============================] - 1s 263us/step - loss: 19077.2513 - val_loss: 19041.5128
# Epoch 10/100
# 2916/2916 [==============================] - 1s 256us/step - loss: 19071.7379 - val_loss: 19027.3952
# Epoch 11/100
# 2916/2916 [==============================] - 1s 249us/step - loss: 19070.7217 - val_loss: 19043.6847
# Epoch 12/100
# 2916/2916 [==============================] - 1s 247us/step - loss: 19051.6734 - val_loss: 19011.5978
# Epoch 13/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 19041.3597 - val_loss: 19007.2116
# Epoch 14/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 19039.1426 - val_loss: 19003.4067
# Epoch 15/100
# 2916/2916 [==============================] - 1s 248us/step - loss: 19031.3133 - val_loss: 18993.5259
# Epoch 16/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 19019.5445 - val_loss: 18991.2529
# Epoch 17/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 19011.2718 - val_loss: 18988.0775
# Epoch 18/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 19016.2177 - val_loss: 19010.3169
# Epoch 19/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 19014.7971 - val_loss: 18993.3358
# Epoch 20/100
# 2916/2916 [==============================] - 1s 249us/step - loss: 19004.4195 - val_loss: 18984.8291
# Epoch 21/100
# 2916/2916 [==============================] - 1s 246us/step - loss: 18991.6742 - val_loss: 18972.8683
# Epoch 22/100
# 2916/2916 [==============================] - 1s 248us/step - loss: 18979.9270 - val_loss: 18960.2750
# Epoch 23/100
# 2916/2916 [==============================] - 1s 247us/step - loss: 18974.8769 - val_loss: 18947.4411
# Epoch 24/100
# 2916/2916 [==============================] - 1s 254us/step - loss: 18963.6848 - val_loss: 18937.2126
# Epoch 25/100
# 2916/2916 [==============================] - 1s 256us/step - loss: 18957.6851 - val_loss: 18935.2850
# Epoch 26/100
# 2916/2916 [==============================] - 1s 259us/step - loss: 18946.4143 - val_loss: 18920.9235
# Epoch 27/100
# 2916/2916 [==============================] - 1s 246us/step - loss: 18944.3332 - val_loss: 18910.4342
# Epoch 28/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 18937.7412 - val_loss: 18910.1562
# Epoch 29/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18931.2612 - val_loss: 18904.4130
# Epoch 30/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18925.5500 - val_loss: 18898.6836
# Epoch 31/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 18924.1866 - val_loss: 18910.3590
# Epoch 32/100
# 2916/2916 [==============================] - 1s 252us/step - loss: 18923.0891 - val_loss: 18891.5547
# Epoch 33/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18916.7616 - val_loss: 18901.1902
# Epoch 34/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 18927.9971 - val_loss: 18922.6506
# Epoch 35/100
# 2916/2916 [==============================] - 1s 247us/step - loss: 18915.0978 - val_loss: 18880.8360
# Epoch 36/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18899.7710 - val_loss: 18871.1571
# Epoch 37/100
# 2916/2916 [==============================] - 1s 258us/step - loss: 18898.8743 - val_loss: 18881.2706
# Epoch 38/100
# 2916/2916 [==============================] - 1s 246us/step - loss: 18898.4542 - val_loss: 18889.0385
# Epoch 39/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18892.8020 - val_loss: 18870.4817
# Epoch 40/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18884.7020 - val_loss: 18855.5832
# Epoch 41/100
# 2916/2916 [==============================] - 1s 250us/step - loss: 18885.0547 - val_loss: 18862.5501
# Epoch 42/100
# 2916/2916 [==============================] - 1s 264us/step - loss: 18888.6168 - val_loss: 18861.3059
# Epoch 43/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 
100
# 2916/2916 [==============================] - 1s 263us/step - loss: 18815.8291 - val_loss: 18780.7164
# Epoch 85/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 18809.5003 - val_loss: 18776.6290
# Epoch 86/100
# 2916/2916 [==============================] - 1s 271us/step - loss: 18803.5098 - val_loss: 18779.5295
# Epoch 87/100
# 2916/2916 [==============================] - 1s 270us/step - loss: 18811.6107 - val_loss: 18773.9110
# Epoch 88/100
# 2916/2916 [==============================] - 1s 269us/step - loss: 18802.1805 - val_loss: 18769.9863
# Epoch 89/100
# 2916/2916 [==============================] - 1s 257us/step - loss: 18800.5344 - val_loss: 18774.6279
# Epoch 90/100
# 2916/2916 [==============================] - 1s 256us/step - loss: 18800.3002 - val_loss: 18765.4252
# Epoch 91/100
# 2916/2916 [==============================] - 1s 260us/step - loss: 18796.5063 - val_loss: 18766.4480
# Epoch 92/100
# 2916/2916 [==============================] - 1s 256us/step - loss: 18804.6219 - val_loss: 18769.0809
# Epoch 93/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18797.8771 - val_loss: 18793.3253
# Epoch 94/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18801.9030 - val_loss: 18760.5578
# Epoch 95/100
# 2916/2916 [==============================] - 1s 266us/step - loss: 18789.9298 - val_loss: 18755.7328
# Epoch 96/100
# 2916/2916 [==============================] - 1s 265us/step - loss: 18786.3029 - val_loss: 18759.3694
# Epoch 97/100
# 2916/2916 [==============================] - 1s 259us/step - loss: 18784.9216 - val_loss: 18752.3885
# Epoch 98/100
# 2916/2916 [==============================] - 1s 251us/step - loss: 18783.3484 - val_loss: 18749.5887
# Epoch 99/100
# 2916/2916 [==============================] - 1s 267us/step - loss: 18779.6690 - val_loss: 18747.6986
# Epoch 100/100
# 2916/2916 [==============================] - 1s 256us/step - loss: 18776.5920 - val_loss: 18747.0141

# %%
z_output = sess.run( z_mean, feed_dict={'encoder_input:0':x_test})

z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
np.zeros((1, 2 )) 
print(z_m_m)

np.cov(z_output.T)
# Out:
# [2.9557247  0.90374446 0.352907  ]
# array([[ 1.46762106, -1.7837145 ,  0.68397628],
#        [-1.7837145 ,  9.91466902,  1.21120545],
#        [ 0.68397628,  1.21120545, 10.63833522]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")

# %%
'''
plot_random_results(models,
                 latent_dim,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
'''
# Out:
# '\nplot_random_results(models,\n                 latent_dim,\n                 z_m_m = z_m_m ,\n                 batch_size=batch_size,\n                 model_name="vae_mlp")\n'

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 4
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input_1')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_1 (InputLayer)    (None, 40000)        0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          8000200     encoder_input_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 4)            804         dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            804         dense_1[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 4)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 8,001,808
# Trainable params: 8,001,808
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               1000
# _________________________________________________________________
# dense_3 (Dense)              (None, 40000)             8040000
# =================================================================
# Total params: 8,041,000
# Trainable params: 8,041,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input_1 (InputLayer) (None, 40000)             0
# _________________________________________________________________
# encoder (Model)              [(None, 4), (None, 4), (N 8001808
# _________________________________________________________________
# decoder (Model)              (None, 40000)             8041000
# =================================================================
# Total params: 16,042,808
# Trainable params: 16,042,808
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 2916 samples, validate on 324 samples
# Epoch 1/100
# 2916/2916 [==============================] - 2s 612us/step - loss: 21281.4584 - val_loss: 19702.4502
# Epoch 2/100
# 2916/2916 [==============================] - 1s 252us/step - loss: 19615.0525 - val_loss: 19461.2804
# Epoch 3/100
# 2916/2916 [==============================] - 1s 254us/step - loss: 19393.0454 - val_loss: 19255.7439
# Epoch 4/100
# 2916/2916 [==============================] - 1s 261us/step - loss: 
100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18640.9155 - val_loss: 18606.7416
# Epoch 97/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18637.4557 - val_loss: 18608.8404
# Epoch 98/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 18637.5281 - val_loss: 18611.8978
# Epoch 99/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 18643.0641 - val_loss: 18608.9110
# Epoch 100/100
# 2916/2916 [==============================] - 1s 236us/step - loss: 18637.8434 - val_loss: 18606.9662

# %%
z_output = sess.run( z_mean, feed_dict={'encoder_input_1:0':x_test})
z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
np.zeros((1, 2 )) 
z_m_m
# Out:
# array([-1.0553424 ,  2.0547645 , -0.07157014, -1.475208  ], dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 9.71466692,  0.70910808, -2.26806005, -1.21258085],
#        [ 0.70910808,  5.95659709,  0.69821424,  2.21762331],
#        [-2.26806005,  0.69821424, 11.12831091,  1.79777188],
#        [-1.21258085,  2.21762331,  1.79777188,  3.32032848]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 5
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input_2')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_2 (InputLayer)    (None, 40000)        0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 200)          8000200     encoder_input_2[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 5)            1005        dense_4[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 5)            1005        dense_4[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 5)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 8,002,210
# Trainable params: 8,002,210
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 5)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 200)               1200
# _________________________________________________________________
# dense_6 (Dense)              (None, 40000)             8040000
# =================================================================
# Total params: 8,041,200
# Trainable params: 8,041,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input_2 (InputLayer) (None, 40000)             0
# _________________________________________________________________
# encoder (Model)              [(None, 5), (None, 5), (N 8002210
# _________________________________________________________________
# decoder (Model)              (None, 40000)             8041200
# =================================================================
# Total params: 16,043,410
# Trainable params: 16,043,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 2916 samples, validate on 324 samples
# Epoch 1/100
# 2916/2916 [==============================] - 1s 455us/step - loss: 25967.1632 - val_loss: 21589.1491
# Epoch 2/100
# 2916/2916 [==============================] - 1s 241us/step - loss: 20846.9527 - val_loss: 20183.6149
# Epoch 3/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 19967.9632 - val_loss: 19766.5397
# Epoch 4/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 19734.3554 - val_loss: 19643.8819
# Epoch 5/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 19622.7224 - val_loss: 19535.0939
# Epoch 6/100
# 2916/2916 [==============================] - 1s 246us/step - loss: 19506.1526 - val_loss: 19420.1212
# Epoch 7/100
# 2916/2916 [==============================] - 1s 248us/step - loss: 19402.0884 - val_loss: 19346.0721
# Epoch 8/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 19347.2721 - val_loss: 19302.3470
# Epoch 9/100
# 2916/2916 [==============================] - 1s 241us/step - loss: 19320.5559 - val_loss: 19284.8123
# Epoch 10/100
# 2916/2916 [==============================] - 1s 237us/step - loss: 19308.9791 - val_loss: 19277.4110
# Epoch 11/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 19299.3385 - val_loss: 19263.7481
# Epoch 12/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 19291.7792 - val_loss: 19256.3029
# Epoch 13/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 19284.1548 - val_loss: 19251.6676
# Epoch 14/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 19279.9708 - val_loss: 19243.8356
# Epoch 15/100
# 2916/2916 [==============================] - 1s 238us/step - loss: 19272.1972 - val_loss: 19247.7996
# Epoch 16/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 19264.3820 - val_loss: 19222.0271
# Epoch 17/100
# 2916/2916 [==============================] - 1s 241us/step - loss: 19247.6303 - val_loss: 19212.6411
# Epoch 18/100
# 2916/2916 [==============================] - 1s 241us/step - loss: 19234.0618 - val_loss: 19186.0925
# Epoch 19/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 19209.1239 - val_loss: 19150.9322
# Epoch 20/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 19164.0193 - val_loss: 19101.5618
# Epoch 21/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 19126.9964 - val_loss: 19077.1223
# Epoch 22/100
# 2916/2916 [==============================] - 1s 239us/step - loss: 19104.2480 - val_loss: 19062.1051
# Epoch 23/100
# 2916/2916 [==============================] - 1s 241us/step - loss:
100
# 2916/2916 [==============================] - 1s 240us/step - loss: 18720.5503 - val_loss: 18698.9853
# Epoch 70/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 18721.1635 - val_loss: 18695.4367
# Epoch 71/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18717.4589 - val_loss: 18695.0497
# Epoch 72/100
# 2916/2916 [==============================] - 1s 240us/step - loss: 18714.4846 - val_loss: 18690.7329
# Epoch 73/100
# 2916/2916 [==============================] - 1s 244us/step - loss: 18711.5443 - val_loss: 18687.3565
# Epoch 74/100
# 2916/2916 [==============================] - 1s 244us/step - loss: 18710.9837 - val_loss: 18687.5312
# Epoch 75/100
# 2916/2916 [==============================] - 1s 244us/step - loss: 18710.1522 - val_loss: 18682.2414
# Epoch 76/100
# 2916/2916 [==============================] - 1s 247us/step - loss: 18707.1705 - val_loss: 18680.9597
# Epoch 77/100
# 2916/2916 [==============================] - 1s 247us/step - loss: 18702.0635 - val_loss: 18681.9413
# Epoch 78/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 18702.1782 - val_loss: 18675.2979
# Epoch 79/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 18699.7992 - val_loss: 18674.0773
# Epoch 80/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18699.8400 - val_loss: 18678.7925
# Epoch 81/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 18695.1062 - val_loss: 18670.8347
# Epoch 82/100
# 2916/2916 [==============================] - 1s 240us/step - loss: 18692.6882 - val_loss: 18669.6321
# Epoch 83/100
# 2916/2916 [==============================] - 1s 241us/step - loss: 18690.7055 - val_loss: 18667.7548
# Epoch 84/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 18688.7808 - val_loss: 18662.4757
# Epoch 85/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 18687.0667 - val_loss: 18661.4207
# Epoch 86/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18693.4106 - val_loss: 18667.7113
# Epoch 87/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18686.1603 - val_loss: 18658.0780
# Epoch 88/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18681.1201 - val_loss: 18655.9455
# Epoch 89/100
# 2916/2916 [==============================] - 1s 246us/step - loss: 18676.9578 - val_loss: 18655.9730
# Epoch 90/100
# 2916/2916 [==============================] - 1s 242us/step - loss: 18677.2293 - val_loss: 18652.1102
# Epoch 91/100
# 2916/2916 [==============================] - 1s 243us/step - loss: 18680.8999 - val_loss: 18650.1483
# Epoch 92/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18678.7177 - val_loss: 18665.0839
# Epoch 93/100
# 2916/2916 [==============================] - 1s 249us/step - loss: 18676.6416 - val_loss: 18650.6401
# Epoch 94/100
# 2916/2916 [==============================] - 1s 244us/step - loss: 18673.7585 - val_loss: 18649.7635
# Epoch 95/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18670.9548 - val_loss: 18656.1046
# Epoch 96/100
# 2916/2916 [==============================] - 1s 244us/step - loss: 18669.1940 - val_loss: 18644.3131
# Epoch 97/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18664.9434 - val_loss: 18651.2028
# Epoch 98/100
# 2916/2916 [==============================] - 1s 246us/step - loss: 18669.4260 - val_loss: 18649.3995
# Epoch 99/100
# 2916/2916 [==============================] - 1s 245us/step - loss: 18665.7568 - val_loss: 18639.4738
# Epoch 100/100
# 2916/2916 [==============================] - 1s 241us/step - loss: 18661.9319 - val_loss: 18638.3180

# %%
z_output = sess.run( z_mean, feed_dict={'encoder_input_2:0':x_test})
z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
#np.zeros((1, 2 )) 
z_m_m
# Out:
# array([-0.78996325, -0.58024764,  2.021188  ,  1.1697673 ,  0.0181012 ],
#       dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 4.95045724, -0.9088204 , -0.17150463, -0.44822252, -0.08519329],
#        [-0.9088204 ,  4.79722137, -0.31869614,  1.0699422 ,  2.19880607],
#        [-0.17150463, -0.31869614,  2.80387275, -3.52543433,  0.64597985],
#        [-0.44822252,  1.0699422 , -3.52543433,  5.06129202, -0.93805224],
#        [-0.08519329,  2.19880607,  0.64597985, -0.93805224,  3.70339323]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
