# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from keras.layers import Lambda, Input, Dense
from keras.models import Model
from keras.datasets import mnist
from keras.losses import mse, binary_crossentropy
from keras.utils import plot_model
from keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import argparse
import os
# Out:
# Using TensorFlow backend.

# %%
import seaborn as sns

# Change figure aesthetics
# %matplotlib inline
sns.set_context('talk', font_scale=1.2, rc={'lines.linewidth': 1.5})

# Load dataset
dataset_zip = np.load('dsprites-dataset/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz'
                      , encoding='bytes')

print('Keys in the dataset:', dataset_zip.keys())
imgs = dataset_zip['imgs']
latents_values = dataset_zip['latents_values']
latents_classes = dataset_zip['latents_classes']
metadata = dataset_zip['metadata'][()]

# Define number of values per latents and functions to convert to indices
latents_sizes =  np.array([ 1,  3,  6, 40, 32, 32])
latents_bases = np.concatenate((latents_sizes[::-1].cumprod()[::-1][1:],
                                np.array([1,])))

def latent_to_index(latents):
  return np.dot(latents, latents_bases).astype(int)

# Helper function to show images
def show_images_grid(imgs_, num_images=25):
  ncols = int(np.ceil(num_images**0.5))
  nrows = int(np.ceil(num_images / ncols))
  _, axes = plt.subplots(ncols, nrows, figsize=(nrows * 3, ncols * 3))
  axes = axes.flatten()

  for ax_i, ax in enumerate(axes):
    if ax_i < num_images:
      ax.imshow(imgs_[ax_i], cmap='Greys_r',  interpolation='nearest')
      ax.set_xticks([])
      ax.set_yticks([])
    else:
      ax.axis('off')

def show_density(imgs):
  _, ax = plt.subplots()
  ax.imshow(imgs.mean(axis=0), interpolation='nearest', cmap='Greys_r')
  ax.grid('off')
  ax.set_xticks([])
  ax.set_yticks([])

from copy import deepcopy
## Fix posX latent to left
#latents_sampled = sample_latent(size=5000)
latents_sampled = deepcopy(latents_classes)
latents_sampled[:, [4,5]] = 15
#latents_sampled[:,2]= 5


indices_sampled = latent_to_index(latents_sampled)
imgs_sampled = imgs[np.unique(indices_sampled)]

#np.unique(indices_sampled)

# Samples
show_images_grid(imgs_sampled,len(np.unique(indices_sampled)))

# Show the density too to check
show_density(imgs_sampled)
# Out:
# Keys in the dataset: KeysView(<numpy.lib.npyio.NpzFile object at 0x7f9d34771a90>)
# /home/shared/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
import random
random.seed(69)
ff = imgs_sampled
n_data =  ff.shape[0]
n_train = int(np.ceil(n_data*0.8))

print(n_train)
idx_train = random.sample(range(n_data), n_train)
idx_test = np.delete(range(n_data),idx_train,0)
# Out:
# 576

# %%
ff.shape[0]*0.8
idx_test
# Out:
# array([  1,   3,  13,  14,  15,  18,  20,  22,  23,  29,  32,  47,  56,
#         58,  61,  62,  69,  70,  76,  78,  86,  88, 106, 109, 112, 114,
#        115, 158, 164, 167, 168, 178, 180, 189, 194, 195, 197, 199, 209,
#        219, 220, 224, 225, 229, 237, 238, 240, 242, 244, 252, 253, 256,
#        266, 273, 274, 277, 286, 287, 290, 294, 297, 298, 300, 301, 304,
#        305, 309, 322, 324, 334, 339, 340, 343, 348, 350, 353, 354, 356,
#        359, 363, 369, 376, 379, 380, 382, 385, 390, 402, 409, 414, 420,
#        435, 440, 444, 446, 449, 453, 457, 462, 464, 465, 479, 486, 491,
#        493, 498, 499, 507, 510, 513, 518, 527, 532, 533, 553, 557, 564,
#        565, 570, 585, 587, 595, 596, 597, 598, 602, 605, 616, 625, 633,
#        644, 647, 652, 657, 658, 661, 673, 674, 677, 680, 689, 702, 708,
#        713])

# %%
# split data into train / validation folds
#np.random.seed(42)

img_rows = ff.shape[1]
img_cols = ff.shape[2]

n_pixels = img_rows * img_cols
x_train = ff[idx_train]
x_test = ff[idx_test]
x_train = x_train.astype('float32')
x_test = x_test.astype('float32') 
x_train = x_train.reshape((len(x_train), n_pixels))
x_test = x_test.reshape((len(x_test), n_pixels))

# %%
x_train.shape
# Out:
# (576, 4096)

# %%
x_test.shape
# Out:
# (144, 4096)

# %%
# def show_examples(data, n=None, n_cols=20, thumbnail_cb=None):
#     if n is None:
#         n = len(data)    
#     n_rows = int(np.ceil(n / float(n_cols)))
#     figure = np.zeros((img_rows * n_rows, img_cols * n_cols))
#     for k, x in enumerate(data[:n]):
#         r = k // n_cols
#         c = k % n_cols
#         figure[r * img_rows: (r + 1) * img_rows,
#                c * img_cols: (c + 1) * img_cols] = x
#         if thumbnail_cb is not None:
#             thumbnail_cb(locals())
        
#     plt.figure(figsize=(64, 64))
#     plt.imshow(figure)
#     plt.axis("off")
#     plt.tight_layout()
# show_examples(ff, n=100, n_cols=25)

# %%
import tensorflow as tf
sess = tf.Session()

K.set_session(sess)

# %%
def sampling(args):
    """Reparameterization trick by sampling fr an isotropic unit Gaussian.

    # Arguments:
        args (tensor): mean and log of variance of Q(z|X)

    # Returns:
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon
#     return z_mean + K.exp(0.5 ) * epsilon

# %%
def plot_results(models,
                 latent_dim,
                 latent_num,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):
    """Plots labels and MNIST digits as function of 2-dim latent vector

    # Arguments:
        models (tuple): encoder and decoder models
        data (tuple): test data and label
        batch_size (int): prediction batch size
        model_name (string): which model is using this function
    """

    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)

    
    
    """filename = os.path.join(model_name, "vae_mean.png")
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = encoder.predict(x_test,
                                   batch_size=batch_size)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=y_test)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.savefig(filename)
    plt.show()
    """

    filename = os.path.join(model_name, "face_over_latent.png")
    n = 20
    #digit_size = 28
    img_rows, img_cols = 64, 64
    figure = np.zeros((img_rows , img_cols * n))
    grid_x = np.linspace(-5, 5, n)
    #grid_x = np.linspace(-2, 2, n)
    
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
    z_sample[0,:] = z_m_m 
    
    for j, xi in enumerate(grid_x):
        z_sample[0,latent_num] = xi
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(img_rows, img_cols)
        figure[0: img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    plt.savefig(filename)
    plt.show()

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 512
intermediate_dim2 = 256
intermediate_dim3 = 64

batch_size = 100
latent_dim = 3
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
x2 = Dense(intermediate_dim2, activation='relu')(x1)
x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x3)
z_log_var = Dense(latent_dim, name='z_log_var')(x3)

# %%
# standardize the mean of z, so that mean(m_z)=0 and cov(m_z)=I
def standardize(z_mean):
    z_m_m = K.mean(z_mean,axis=0, keepdims=True)
    z1 = z_mean - z_m_m
    n = tf.cast(K.shape(z_mean)[0], tf.float32)
    cov = K.transpose(z1) @ z1 /n
    
    D = tf.diag(tf.diag_part(cov)) ** 0.5
    
    L = tf.linalg.inv(tf.transpose(tf.cholesky(cov)))
       
#     z2 = z1 @ L @ D +  z_m_m
    z2 = z1 @ L  +  z_m_m

    return( z2)

# %%
z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
#z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])
# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 4096)         0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          2097664     encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           16448       dense_2[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 3)            195         dense_3[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 3)            195         dense_3[0][0]
# __________________________________________________________________________________________________
# z_mean_std (Lambda)             (None, 3)            0           z_mean[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 3)            0           z_mean_std[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 2,245,830
# Trainable params: 2,245,830
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z')

x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(x2)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z (InputLayer)               (None, 3)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                256
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               16640
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_7 (Dense)              (None, 4096)              2101248
# =================================================================
# Total params: 2,249,728
# Trainable params: 2,249,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 4096)              0
# _________________________________________________________________
# encoder (Model)              [(None, 3), (None, 3), (N 2245830
# _________________________________________________________________
# decoder (Model)              (None, 4096)              2249728
# =================================================================
# Total params: 4,495,558
# Trainable params: 4,495,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(500)

# %%
from keras.callbacks import ModelCheckpoint

'''
saves the model weights after each epoch if the validation loss decreased
'''
checkpointer = ModelCheckpoint(filepath='weights.hdf5', verbose=1, save_best_only=True)
#model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=0, validation_data=(X_test, Y_test), callbacks=[checkpointer])
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None), 
        callbacks=[checkpointer])
# Out:
# Train on 576 samples, validate on 144 samples
# Epoch 1/500
# 576/576 [==============================] - 1s 3ms/step - loss: 2571.9432 - val_loss: 1314.6366
#
# Epoch 00001: val_loss improved from inf to 1314.63663, saving model to weights.hdf5
# Epoch 2/500
# 576/576 [==============================] - 0s 119us/step - loss: 685.0027 - val_loss: 449.7337
#
# Epoch 00002: val_loss improved from 1314.63663 to 449.73369, saving model to weights.hdf5
# Epoch 3/500
# 576/576 [==============================] - 0s 113us/step - loss: 384.4316 - val_loss: 285.6391
#
# Epoch 00003: val_loss improved from 449.73369 to 285.63908, saving model to weights.hdf5
# Epoch 4/500
# 576/576 [==============================] - 0s 117us/step - loss: 249.8309 - val_loss: 221.9458
#
# Epoch 00004: val_loss improved from 285.63908 to 221.94581, saving model to weights.hdf5
# Epoch 5/500
# 576/576 [==============================] - 0s 115us/step - loss: 212.5817 - val_loss: 208.9132
#
# Epoch 00005: val_loss improved from 221.94581 to 208.91316, saving model to weights.hdf5
# Epoch 6/500
# 576/576 [==============================] - 0s 115us/step - loss: 200.4075 - val_loss: 195.6471
#
# Epoch 00006: val_loss improved from 208.91316 to 195.64711, saving model to weights.hdf5
# Epoch 7/500
# 576/576 [==============================] - 0s 119us/step - loss: 189.9534 - val_loss: 187.4387
#
# Epoch 00007: val_loss improved from 195.64711 to 187.43871, saving model to weights.hdf5
# Epoch 8/500
# 576/576 [==============================] - 0s 114us/step - loss: 184.3024 - val_loss: 179.0762
#
# Epoch 00008: val_loss improved from 187.43871 to 179.07619, saving model to weights.hdf5
# Epoch 9/500
# 576/576 [==============================] - 0s 111us/step - loss: 172.3329 - val_loss: 163.9466
#
# Epoch 00009: val_loss improved from 179.07619 to 163.94663, saving model to weights.hdf5
# Epoch 10/500
# 576/576 [==============================] - 0s 116us/step - loss: 160.7632 - val_loss: 153.8135
#
# Epoch 00010: val_loss improved from 163.94663 to 153.81351, saving model to weights.hdf5
# Epoch 11/500
# 576/576 [==============================] - 0s 114us/step - loss: 149.6290 - val_loss: 145.6545
#
# Epoch 00011: val_loss improved from 153.81351 to 145.65455, saving model to weights.hdf5
# Epoch 12/500
# 576/576 [==============================] - 0s 112us/step - loss: 139.6309 - val_loss: 134.1975
#
# Epoch 00012: val_loss improved from 145.65455 to 134.19746, saving model to weights.hdf5
# Epoch 13/500
# 576/576 [==============================] - 0s 115us/step - loss: 132.6027 - val_loss: 130.5916
#
# Epoch 00013: val_loss improved from 134.19746 to 130.59158, saving model to weights.hdf5
# Epoch 14/500
# 576/576 [==============================] - 0s 115us/step - loss: 129.0131 - val_loss: 135.3219
#
# Epoch 00014: val_loss did not improve from 130.59158
# Epoch 15/500
# 576/576 [==============================] - 0s 123us/step - loss: 126.8654 - val_loss: 126.2093
#
# Epoch 00015: val_loss improved from 130.59158 to 126.20927, saving model to weights.hdf5
# Epoch 16/500
# 576/576 [==============================] - 0s 112us/step - loss: 122.4780 - val_loss: 122.4488
#
# Epoch 00016: val_loss improved from 126.20927 to 122.44880, saving model to weights.hdf5
# Epoch 17/500
# 576/576 [==============================] - 0s 112us/step - loss: 120.3740 - val_loss: 127.2372
#
# Epoch 00017: val_loss did not improve from 122.44880
# Epoch 18/500
# 576/576 [==============================] - 0s 122us/step - loss: 121.8995 - val_loss: 120.6188
#
# Epoch 00018: val_loss improved from 122.44880 to 120.61881, saving model to weights.hdf5
# Epoch 19/500
# 576/576 [==============================] - 0s 113us/step - loss: 118.9852 - val_loss: 120.9680
#
# Epoch 00019: val_loss did not improve from 120.61881
# Epoch 20/500
# 576/576 [==============================] - 0s 118us/step - loss: 118.3481 - val_loss: 118.6292
#
# Epoch 00020: val_loss improved from 120.61881 to 118.62925, saving model to weights.hdf5
# Epoch 21/500
# 576/576 [==============================] - 0s 111us/step - loss: 116.9532 - val_loss: 126.5542
#
# Epoch 00021: val_loss did not improve from 118.62925
# Epoch 22/500
# 576/576 [==============================] - 0s 120us/step - loss: 117.3024 - val_loss: 118.4085
#
# Epoch 00022: val_loss improved from 118.62925 to 118.40848, saving model to weights.hdf5
# Epoch 23/500
# 576/576 [==============================] - 0s 115us/step - loss: 113.9535 - val_loss: 116.9983
#
# Epoch 00023: val_loss improved from 118.40848 to 116.99829, saving model to weights.hdf5
# Epoch 24/500
# 576/576 [==============================] - 0s 111us/step - loss: 112.7003 - val_loss: 119.5369
#
# Epoch 00024: val_loss did not improve from 116.99829
# Epoch 25/500
# 576/576 [==============================] - 0s 120us/step - loss: 112.1548 - val_loss: 118.9579
#
# Epoch 00025: val_loss did not improve from 116.99829
# Epoch 26/500
# 576/576 [==============================] - 0s 127us/step - loss: 113.2654 - val_loss: 115.3144
#
# Epoch 00026: val_loss improved from 116.99829 to 115.31441, saving model to weights.hdf5
# Epoch 27/500
# 576/576 [==============================] - 0s 114us/step - loss: 113.3502 - val_loss: 113.4958
#
# Epoch 00027: val_loss improved from 115.31441 to 113.49580, saving model to weights.hdf5
# Epoch 28/500
# 576/576 [==============================] - 0s 137us/step - loss: 100.4319 - val_loss: 108.4307
#
# Epoch 00046: val_loss did not improve from 106.67042
# Epoch 47/500
# 576/576 [==============================] - 0s 134us/step - loss: 100.8769 - val_loss: 107.4816
#
# Epoch 00047: val_loss did not improve from 106.67042
# Epoch 48/500
# 576/576 [==============================] - 0s 133us/step - loss: 99.4919 - val_loss: 106.9017
#
# Epoch 00048: val_loss did not improve from 106.67042
# Epoch 49/500
# 576/576 [==============================] - 0s 137us/step - loss: 101.5899 - val_loss: 107.5034
#
# Epoch 00049: val_loss did not improve from 106.67042
# Epoch 50/500
# 576/576 [==============================] - 0s 137us/step - loss: 100.4405 - val_loss: 106.2797
#
# Epoch 00050: val_loss improved from 106.67042 to 106.27969, saving model to weights.hdf5
# Epoch 51/500
# 576/576 [==============================] - 0s 117us/step - loss: 100.2915 - val_loss: 108.1570
#
# Epoch 00051: val_loss did not improve from 106.27969
# Epoch 52/500
# 576/576 [==============================] - 0s 125us/step - loss: 100.0750 - val_loss: 109.1908
#
# Epoch 00052: val_loss did not improve from 106.27969
# Epoch 53/500
# 576/576 [==============================] - 0s 131us/step - loss: 99.5055 - val_loss: 106.1220
#
# Epoch 00053: val_loss improved from 106.27969 to 106.12203, saving model to weights.hdf5
# Epoch 54/500
# 576/576 [==============================] - 0s 113us/step - loss: 98.6110 - val_loss: 107.2306
#
# Epoch 00054: val_loss did not improve from 106.12203
# Epoch 55/500
# 576/576 [==============================] - 0s 121us/step - loss: 99.1153 - val_loss: 111.5106
#
# Epoch 00055: val_loss did not improve from 106.12203
# Epoch 56/500
# 576/576 [==============================] - 0s 129us/step - loss: 101.0662 - val_loss: 111.6243
#
# Epoch 00056: val_loss did not improve from 106.12203
# Epoch 57/500
# 576/576 [==============================] - 0s 135us/step - loss: 100.9949 - val_loss: 108.6593
#
# Epoch 00057: val_loss did not improve from 106.12203
# Epoch 58/500
# 576/576 [==============================] - 0s 136us/step - loss: 100.8659 - val_loss: 106.9074
#
# Epoch 00058: val_loss did not improve from 106.12203
# Epoch 59/500
# 576/576 [==============================] - 0s 132us/step - loss: 100.3671 - val_loss: 109.0709
#
# Epoch 00059: val_loss did not improve from 106.12203
# Epoch 60/500
# 576/576 [==============================] - 0s 136us/step - loss: 99.2290 - val_loss: 109.8737
#
# Epoch 00060: val_loss did not improve from 106.12203
# Epoch 61/500
# 576/576 [==============================] - 0s 138us/step - loss: 100.1812 - val_loss: 107.4857
#
# Epoch 00061: val_loss did not improve from 106.12203
# Epoch 62/500
# 576/576 [==============================] - 0s 136us/step - loss: 99.5230 - val_loss: 107.5595
#
# Epoch 00062: val_loss did not improve from 106.12203
# Epoch 63/500
# 576/576 [==============================] - 0s 138us/step - loss: 99.3829 - val_loss: 110.3285
#
# Epoch 00063: val_loss did not improve from 106.12203
# Epoch 64/500
# 576/576 [==============================] - 0s 137us/step - loss: 97.7605 - val_loss: 106.0326
#
# Epoch 00064: val_loss improved from 106.12203 to 106.03260, saving model to weights.hdf5
# Epoch 123/500
# 576/576 [==============================] - 0s 138us/step - loss: 88.5884 - val_loss: 114.6158
#
# Epoch 00123: val_loss did not improve from 106.03260
# Epoch 124/500
# 576/576 [==============================] - 0s 140us/step - loss: 88.6271 - val_loss: 120.5688
#
# Epoch 00124: val_loss did not improve from 106.03260
# Epoch 125/500
# 576/576 [==============================] - 0s 135us/step - loss: 91.6733 - val_loss: 110.8921
#
# Epoch 00125: val_loss did not improve from 106.03260
# Epoch 126/500
# 576/576 [==============================] - 0s 135us/step - loss: 89.7951 - val_loss: 114.4739
#
# Epoch 00126: val_loss did not improve from 106.03260
# Epoch 127/500
# 576/576 [==============================] - 0s 134us/step - loss: 88.7849 - val_loss: 115.0636
#
# Epoch 00127: val_loss did not improve from 106.03260
# Epoch 128/500
# 576/576 [==============================] - 0s 136us/step - loss: 88.7851 - val_loss: 110.9147
#
# Epoch 00128: val_loss did not improve from 106.03260
# Epoch 129/500
# 576/576 [==============================] - 0s 139us/step - loss: 87.3257 - val_loss: 111.7604
#
# Epoch 00129: val_loss did not improve from 106.03260
# Epoch 130/500
# 576/576 [==============================] - 0s 139us/step - loss: 86.2759 - val_loss: 115.8824
#
# Epoch 00130: val_loss did not improve from 106.03260
# Epoch 131/500
# 576/576 [==============================] - 0s 138us/step - loss: 85.8108 - val_loss: 114.0698
#
# Epoch 00131: val_loss did not improve from 106.03260
# Epoch 132/500
# 576/576 [==============================] - 0s 136us/step - loss: 86.5176 - val_loss: 114.9510
#
# Epoch 00132: val_loss did not improve from 106.03260
# Epoch 133/500
# 576/576 [==============================] - 0s 138us/step - loss: 88.1927 - val_loss: 114.0701
#
# Epoch 00133: val_loss did not improve from 106.03260
# Epoch 134/500
# 576/576 [==============================] - 0s 139us/step - loss: 84.6339 - val_loss: 111.4668
#
# Epoch 00134: val_loss did not improve from 106.03260
# Epoch 135/500
# 576/576 [==============================] - 0s 136us/step - loss: 84.9265 - val_loss: 116.8967
#
# Epoch 00135: val_loss did not improve from 106.03260
# Epoch 136/500
# 576/576 [==============================] - 0s 135us/step - loss: 85.1450 - val_loss: 113.6571
#
# Epoch 00136: val_loss did not improve from 106.03260
# Epoch 137/500
# 576/576 [==============================] - 0s 138us/step - loss: 85.0881 - val_loss: 114.4134
#
# Epoch 00137: val_loss did not improve from 106.03260
# Epoch 138/500
# 576/576 [==============================] - 0s 132us/step - loss: 84.7302 - val_loss: 118.1308
#
# Epoch 00138: val_loss did not improve from 106.03260
# Epoch 139/500
# 576/576 [==============================] - 0s 137us/step - loss: 87.5424 - val_loss: 114.2787
#
# Epoch 00139: val_loss did not improve from 106.03260
# Epoch 140/500
# 576/576 [==============================] - 0s 135us/step - loss: 88.1604 - val_loss: 114.5707
#
# Epoch 00140: val_loss did not improve from 106.03260
# Epoch 141/500
# 576/576 [==============================] - 0s 138us/step - loss: 85.8767 - val_loss: 117.4713
#
# Epoch 00141: val_loss did not improve from 106.03260
# Epoch 142/500
# Epoch 487/500
# 576/576 [==============================] - 0s 138us/step - loss: 45.5167 - val_loss: 138.9270
#
# Epoch 00487: val_loss did not improve from 106.03260
# Epoch 488/500
# 576/576 [==============================] - 0s 137us/step - loss: 43.3305 - val_loss: 141.3267
#
# Epoch 00488: val_loss did not improve from 106.03260
# Epoch 489/500
# 576/576 [==============================] - 0s 136us/step - loss: 46.3979 - val_loss: 140.3597
#
# Epoch 00489: val_loss did not improve from 106.03260
# Epoch 490/500
# 576/576 [==============================] - 0s 135us/step - loss: 45.1295 - val_loss: 136.6878
#
# Epoch 00490: val_loss did not improve from 106.03260
# Epoch 491/500
# 576/576 [==============================] - 0s 136us/step - loss: 46.3746 - val_loss: 138.6934
#
# Epoch 00491: val_loss did not improve from 106.03260
# Epoch 492/500
# 576/576 [==============================] - 0s 136us/step - loss: 43.7431 - val_loss: 145.6529
#
# Epoch 00492: val_loss did not improve from 106.03260
# Epoch 493/500
# 576/576 [==============================] - 0s 135us/step - loss: 48.9415 - val_loss: 150.2705
#
# Epoch 00493: val_loss did not improve from 106.03260
# Epoch 494/500
# 576/576 [==============================] - 0s 135us/step - loss: 47.7817 - val_loss: 142.0937
#
# Epoch 00494: val_loss did not improve from 106.03260
# Epoch 495/500
# 576/576 [==============================] - 0s 139us/step - loss: 45.6719 - val_loss: 148.4135
#
# Epoch 00495: val_loss did not improve from 106.03260
# Epoch 496/500
# 576/576 [==============================] - 0s 136us/step - loss: 49.2005 - val_loss: 150.6108
#
# Epoch 00496: val_loss did not improve from 106.03260
# Epoch 497/500
# 576/576 [==============================] - 0s 137us/step - loss: 45.8187 - val_loss: 142.1088
#
# Epoch 00497: val_loss did not improve from 106.03260
# Epoch 498/500
# 576/576 [==============================] - 0s 137us/step - loss: 47.8961 - val_loss: 141.4899
#
# Epoch 00498: val_loss did not improve from 106.03260
# Epoch 499/500
# 576/576 [==============================] - 0s 136us/step - loss: 43.2587 - val_loss: 144.0611
# Epoch 00499: val_loss did not improve from 106.03260
# Epoch 500/500
# 576/576 [==============================] - 0s 137us/step - loss: 42.8403 - val_loss: 143.4989
#
# Epoch 00500: val_loss did not improve from 106.03260

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input: 0':x_train})

# %%
z_m_m = np.mean(z_output,axis=0)
z_m_m
# Out:
# array([-0.08180149,  0.11176732, -0.01582662], dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 1.00173903e+00, -1.04235571e-08,  4.65411345e-09],
#        [-1.04235571e-08,  1.00173907e+00,  7.17599452e-09],
#        [ 4.65411345e-09,  7.17599452e-09,  1.00173910e+00]])

# %% [markdown]
# Plot the Pearson correlation among Z

# %%
plt.matshow(np.corrcoef(z_output.T))

# %%
z_m_m
# Out:
# array([-0.08180149,  0.11176732, -0.01582662], dtype=float32)

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
