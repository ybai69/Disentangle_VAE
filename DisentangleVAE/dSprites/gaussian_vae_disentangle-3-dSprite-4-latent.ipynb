# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from keras.layers import Lambda, Input, Dense
from keras.models import Model
from keras.datasets import mnist
from keras.losses import mse, binary_crossentropy
from keras.utils import plot_model
from keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import argparse
import os
# Out:
# Using TensorFlow backend.

# %%
import seaborn as sns

# Change figure aesthetics
# %matplotlib inline
sns.set_context('talk', font_scale=1.2, rc={'lines.linewidth': 1.5})

# Load dataset
dataset_zip = np.load('dsprites-dataset/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz'
                      , encoding='bytes')

print('Keys in the dataset:', dataset_zip.keys())
imgs = dataset_zip['imgs']
latents_values = dataset_zip['latents_values']
latents_classes = dataset_zip['latents_classes']
metadata = dataset_zip['metadata'][()]

# Define number of values per latents and functions to convert to indices
latents_sizes =  np.array([ 1,  3,  6, 40, 32, 32])
latents_bases = np.concatenate((latents_sizes[::-1].cumprod()[::-1][1:],
                                np.array([1,])))

def latent_to_index(latents):
  return np.dot(latents, latents_bases).astype(int)

# Helper function to show images
def show_images_grid(imgs_, num_images=25):
  ncols = int(np.ceil(num_images**0.5))
  nrows = int(np.ceil(num_images / ncols))
  _, axes = plt.subplots(ncols, nrows, figsize=(nrows * 3, ncols * 3))
  axes = axes.flatten()

  for ax_i, ax in enumerate(axes):
    if ax_i < num_images:
      ax.imshow(imgs_[ax_i], cmap='Greys_r',  interpolation='nearest')
      ax.set_xticks([])
      ax.set_yticks([])
    else:
      ax.axis('off')

def show_density(imgs):
  _, ax = plt.subplots()
  ax.imshow(imgs.mean(axis=0), interpolation='nearest', cmap='Greys_r')
  ax.grid('off')
  ax.set_xticks([])
  ax.set_yticks([])

from copy import deepcopy
## Fix posX latent to left
#latents_sampled = sample_latent(size=5000)
latents_sampled = deepcopy(latents_classes)
latents_sampled[:, [4,5]] = 15
#latents_sampled[:,2]= 5


indices_sampled = latent_to_index(latents_sampled)
imgs_sampled = imgs[np.unique(indices_sampled)]

#np.unique(indices_sampled)

# Samples
show_images_grid(imgs_sampled,len(np.unique(indices_sampled)))

# Show the density too to check
show_density(imgs_sampled)
# Out:
# Keys in the dataset: KeysView(<numpy.lib.npyio.NpzFile object at 0x7f26065d8ac8>)
# /home/shared/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
import random
random.seed(69)
ff = imgs_sampled
n_data =  ff.shape[0]
n_train = int(np.ceil(n_data*0.8))

print(n_train)
idx_train = random.sample(range(n_data), n_train)
idx_test = np.delete(range(n_data),idx_train,0)
# Out:
# 576

# %%
ff.shape[0]*0.8
idx_test
# Out:
# array([  1,   3,  13,  14,  15,  18,  20,  22,  23,  29,  32,  47,  56,
#         58,  61,  62,  69,  70,  76,  78,  86,  88, 106, 109, 112, 114,
#        115, 158, 164, 167, 168, 178, 180, 189, 194, 195, 197, 199, 209,
#        219, 220, 224, 225, 229, 237, 238, 240, 242, 244, 252, 253, 256,
#        266, 273, 274, 277, 286, 287, 290, 294, 297, 298, 300, 301, 304,
#        305, 309, 322, 324, 334, 339, 340, 343, 348, 350, 353, 354, 356,
#        359, 363, 369, 376, 379, 380, 382, 385, 390, 402, 409, 414, 420,
#        435, 440, 444, 446, 449, 453, 457, 462, 464, 465, 479, 486, 491,
#        493, 498, 499, 507, 510, 513, 518, 527, 532, 533, 553, 557, 564,
#        565, 570, 585, 587, 595, 596, 597, 598, 602, 605, 616, 625, 633,
#        644, 647, 652, 657, 658, 661, 673, 674, 677, 680, 689, 702, 708,
#        713])

# %%
# split data into train / validation folds
#np.random.seed(42)

img_rows = ff.shape[1]
img_cols = ff.shape[2]

n_pixels = img_rows * img_cols
x_train = ff[idx_train]
x_test = ff[idx_test]
x_train = x_train.astype('float32')
x_test = x_test.astype('float32') 
x_train = x_train.reshape((len(x_train), n_pixels))
x_test = x_test.reshape((len(x_test), n_pixels))

# %%
x_train.shape
# Out:
# (576, 4096)

# %%
x_test.shape
# Out:
# (144, 4096)

# %%
# def show_examples(data, n=None, n_cols=20, thumbnail_cb=None):
#     if n is None:
#         n = len(data)    
#     n_rows = int(np.ceil(n / float(n_cols)))
#     figure = np.zeros((img_rows * n_rows, img_cols * n_cols))
#     for k, x in enumerate(data[:n]):
#         r = k // n_cols
#         c = k % n_cols
#         figure[r * img_rows: (r + 1) * img_rows,
#                c * img_cols: (c + 1) * img_cols] = x
#         if thumbnail_cb is not None:
#             thumbnail_cb(locals())
        
#     plt.figure(figsize=(64, 64))
#     plt.imshow(figure)
#     plt.axis("off")
#     plt.tight_layout()
# show_examples(ff, n=100, n_cols=25)

# %%
import tensorflow as tf
sess = tf.Session()

K.set_session(sess)

# %%
def sampling(args):
    """Reparameterization trick by sampling fr an isotropic unit Gaussian.

    # Arguments:
        args (tensor): mean and log of variance of Q(z|X)

    # Returns:
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon
#     return z_mean + K.exp(0.5 ) * epsilon

# %%
def plot_results(models,
                 latent_dim,
                 latent_num,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):
    """Plots labels and MNIST digits as function of 2-dim latent vector

    # Arguments:
        models (tuple): encoder and decoder models
        data (tuple): test data and label
        batch_size (int): prediction batch size
        model_name (string): which model is using this function
    """

    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)

    
    
    """filename = os.path.join(model_name, "vae_mean.png")
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = encoder.predict(x_test,
                                   batch_size=batch_size)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=y_test)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.savefig(filename)
    plt.show()
    """

    filename = os.path.join(model_name, "face_over_latent.png")
    n = 20
    #digit_size = 28
    img_rows, img_cols = 64, 64
    figure = np.zeros((img_rows , img_cols * n))
    grid_x = np.linspace(-5, 5, n)
    #grid_x = np.linspace(-2, 2, n)
    
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
    z_sample[0,:] = z_m_m 
    
    for j, xi in enumerate(grid_x):
        z_sample[0,latent_num] = xi
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(img_rows, img_cols)
        figure[0: img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    plt.savefig(filename)
    plt.show()

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 512
intermediate_dim2 = 256
intermediate_dim3 = 64

batch_size = 100
latent_dim = 4
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
x2 = Dense(intermediate_dim2, activation='relu')(x1)
x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x3)
z_log_var = Dense(latent_dim, name='z_log_var')(x3)

# %%
# standardize the mean of z, so that mean(m_z)=0 and cov(m_z)=I
def standardize(z_mean):
    z_m_m = K.mean(z_mean,axis=0, keepdims=True)
    z1 = z_mean - z_m_m
    n = tf.cast(K.shape(z_mean)[0], tf.float32)
    cov = K.transpose(z1) @ z1 /n
    
    D = tf.diag(tf.diag_part(cov)) ** 0.5
    
    L = tf.linalg.inv(tf.transpose(tf.cholesky(cov)))
       
#     z2 = z1 @ L @ D +  z_m_m
    z2 = z1 @ L  +  z_m_m

    return( z2)

# %%
z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
#z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])
# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 4096)         0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          2097664     encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           16448       dense_2[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 4)            260         dense_3[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 4)            260         dense_3[0][0]
# __________________________________________________________________________________________________
# z_mean_std (Lambda)             (None, 4)            0           z_mean[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 4)            0           z_mean_std[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 2,245,960
# Trainable params: 2,245,960
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z')

x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(x2)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z (InputLayer)               (None, 4)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                320
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               16640
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_7 (Dense)              (None, 4096)              2101248
# =================================================================
# Total params: 2,249,792
# Trainable params: 2,249,792
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 4096)              0
# _________________________________________________________________
# encoder (Model)              [(None, 4), (None, 4), (N 2245960
# _________________________________________________________________
# decoder (Model)              (None, 4096)              2249792
# =================================================================
# Total params: 4,495,752
# Trainable params: 4,495,752
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = int(500)

# %%
from keras.callbacks import ModelCheckpoint

'''
saves the model weights after each epoch if the validation loss decreased
'''
checkpointer = ModelCheckpoint(filepath='weights.hdf5', verbose=1, save_best_only=True)
#model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=0, validation_data=(X_test, Y_test), callbacks=[checkpointer])
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None), 
        callbacks=[checkpointer])
# Out:
# Train on 576 samples, validate on 144 samples
# Epoch 1/500
# 576/576 [==============================] - 1s 3ms/step - loss: 2650.0252 - val_loss: 1792.0272
#
# Epoch 00001: val_loss improved from inf to 1792.02723, saving model to weights.hdf5
# Epoch 2/500
# 576/576 [==============================] - 0s 118us/step - loss: 974.9678 - val_loss: 312.8502
#
# Epoch 00002: val_loss improved from 1792.02723 to 312.85021, saving model to weights.hdf5
# Epoch 3/500
# 576/576 [==============================] - 0s 117us/step - loss: 255.4061 - val_loss: 238.7501
#
# Epoch 00003: val_loss improved from 312.85021 to 238.75008, saving model to weights.hdf5
# Epoch 4/500
# 576/576 [==============================] - 0s 114us/step - loss: 223.8659 - val_loss: 198.0523
#
# Epoch 00004: val_loss improved from 238.75008 to 198.05230, saving model to weights.hdf5
# Epoch 5/500
# 576/576 [==============================] - 0s 109us/step - loss: 193.3520 - val_loss: 183.2692
#
# Epoch 00005: val_loss improved from 198.05230 to 183.26917, saving model to weights.hdf5
# Epoch 6/500
# 576/576 [==============================] - 0s 112us/step - loss: 185.7106 - val_loss: 177.9553
#
# Epoch 00006: val_loss improved from 183.26917 to 177.95535, saving model to weights.hdf5
# Epoch 7/500
# 576/576 [==============================] - 0s 115us/step - loss: 179.3126 - val_loss: 174.8613
#
# Epoch 00007: val_loss improved from 177.95535 to 174.86130, saving model to weights.hdf5
# Epoch 8/500
# 576/576 [==============================] - 0s 112us/step - loss: 176.1234 - val_loss: 173.7791
#
# Epoch 00008: val_loss improved from 174.86130 to 173.77911, saving model to weights.hdf5
# Epoch 9/500
# 576/576 [==============================] - 0s 111us/step - loss: 172.2123 - val_loss: 167.4102
#
# Epoch 00009: val_loss improved from 173.77911 to 167.41017, saving model to weights.hdf5
# Epoch 10/500
# 576/576 [==============================] - 0s 109us/step - loss: 165.0810 - val_loss: 159.8285
#
# Epoch 00010: val_loss improved from 167.41017 to 159.82846, saving model to weights.hdf5
# Epoch 11/500
# 576/576 [==============================] - 0s 106us/step - loss: 156.0918 - val_loss: 151.9864
#
# Epoch 00011: val_loss improved from 159.82846 to 151.98642, saving model to weights.hdf5
# Epoch 12/500
# 576/576 [==============================] - 0s 115us/step - loss: 146.0881 - val_loss: 144.0073
#
# Epoch 00012: val_loss improved from 151.98642 to 144.00735, saving model to weights.hdf5
# Epoch 13/500
# 576/576 [==============================] - 0s 108us/step - loss: 136.7946 - val_loss: 131.8779
#
# Epoch 00013: val_loss improved from 144.00735 to 131.87785, saving model to weights.hdf5
# Epoch 14/500
# 576/576 [==============================] - 0s 115us/step - loss: 129.8304 - val_loss: 128.9673
#
# Epoch 00014: val_loss improved from 131.87785 to 128.96727, saving model to weights.hdf5
# Epoch 15/500
# 576/576 [==============================] - 0s 112us/step - loss: 124.6407 - val_loss: 128.6996
#
# Epoch 00015: val_loss improved from 128.96727 to 128.69964, saving model to weights.hdf5
# Epoch 16/500
# 576/576 [==============================] - 0s 119us/step - loss: 122.7911 - val_loss: 124.7497
#
# Epoch 00016: val_loss improved from 128.69964 to 124.74972, saving model to weights.hdf5
# Epoch 17/500
# 576/576 [==============================] - 0s 114us/step - loss: 119.9354 - val_loss: 124.2370
#
# Epoch 00017: val_loss improved from 124.74972 to 124.23698, saving model to weights.hdf5
# Epoch 18/500
# 576/576 [==============================] - 0s 122us/step - loss: 120.7161 - val_loss: 124.9051
#
# Epoch 00018: val_loss did not improve from 124.23698
# Epoch 19/500
# 576/576 [==============================] - 0s 126us/step - loss: 118.6807 - val_loss: 125.9979
#
# Epoch 00019: val_loss did not improve from 124.23698
# Epoch 20/500
# 576/576 [==============================] - 0s 138us/step - loss: 119.9470 - val_loss: 121.0896
#
# Epoch 00020: val_loss improved from 124.23698 to 121.08956, saving model to weights.hdf5
# Epoch 21/500
# 576/576 [==============================] - 0s 112us/step - loss: 118.7781 - val_loss: 120.6218
#
# Epoch 00021: val_loss improved from 121.08956 to 120.62181, saving model to weights.hdf5
# Epoch 22/500
# 576/576 [==============================] - 0s 119us/step - loss: 117.6481 - val_loss: 123.9691
#
# Epoch 00022: val_loss did not improve from 120.62181
# Epoch 23/500
# 576/576 [==============================] - 0s 125us/step - loss: 115.5405 - val_loss: 118.9860
#
# Epoch 00023: val_loss improved from 120.62181 to 118.98597, saving model to weights.hdf5
# Epoch 24/500
# 576/576 [==============================] - 0s 116us/step - loss: 115.3315 - val_loss: 117.6913
#
# Epoch 00024: val_loss improved from 118.98597 to 117.69131, saving model to weights.hdf5
# Epoch 25/500
# 576/576 [==============================] - 0s 116us/step - loss: 113.3082 - val_loss: 116.3909
#
# Epoch 00025: val_loss improved from 117.69131 to 116.39094, saving model to weights.hdf5
# Epoch 26/500
# 576/576 [==============================] - 0s 113us/step - loss: 110.8507 - val_loss: 114.9120
#
# Epoch 00026: val_loss improved from 116.39094 to 114.91199, saving model to weights.hdf5
# Epoch 27/500
# 576/576 [==============================] - 0s 114us/step - loss: 112.4293 - val_loss: 116.5752
#
# Epoch 00027: val_loss did not improve from 114.91199
# Epoch 28/500
# 576/576 [==============================] - 0s 120us/step - loss: 113.0811 - val_loss: 115.7811
#
# Epoch 00046: val_loss did not improve from 108.78397
# Epoch 47/500
# 576/576 [==============================] - 0s 122us/step - loss: 99.1163 - val_loss: 110.5569
#
# Epoch 00047: val_loss did not improve from 108.78397
# Epoch 48/500
# 576/576 [==============================] - 0s 129us/step - loss: 101.5921 - val_loss: 107.5026
#
# Epoch 00048: val_loss improved from 108.78397 to 107.50261, saving model to weights.hdf5
# Epoch 49/500
# 576/576 [==============================] - 0s 120us/step - loss: 98.7320 - val_loss: 106.5652
#
# Epoch 00049: val_loss improved from 107.50261 to 106.56516, saving model to weights.hdf5
# Epoch 50/500
# 576/576 [==============================] - 0s 119us/step - loss: 98.1941 - val_loss: 110.1812
#
# Epoch 00050: val_loss did not improve from 106.56516
# Epoch 51/500
# 576/576 [==============================] - 0s 122us/step - loss: 98.0117 - val_loss: 108.9547
#
# Epoch 00051: val_loss did not improve from 106.56516
# Epoch 52/500
# 576/576 [==============================] - 0s 132us/step - loss: 97.4227 - val_loss: 106.4758
#
# Epoch 00052: val_loss improved from 106.56516 to 106.47582, saving model to weights.hdf5
# Epoch 53/500
# 576/576 [==============================] - 0s 120us/step - loss: 97.6848 - val_loss: 110.2995
#
# Epoch 00053: val_loss did not improve from 106.47582
# Epoch 54/500
# 576/576 [==============================] - 0s 127us/step - loss: 98.2809 - val_loss: 110.9783
#
# Epoch 00054: val_loss did not improve from 106.47582
# Epoch 55/500
# 576/576 [==============================] - 0s 133us/step - loss: 97.2452 - val_loss: 105.5553
#
# Epoch 00055: val_loss improved from 106.47582 to 105.55533, saving model to weights.hdf5
# Epoch 56/500
# 576/576 [==============================] - 0s 116us/step - loss: 96.0392 - val_loss: 110.6519
#
# Epoch 00056: val_loss did not improve from 105.55533
# Epoch 57/500
# 576/576 [==============================] - 0s 120us/step - loss: 97.1280 - val_loss: 105.9078
#
# Epoch 00057: val_loss did not improve from 105.55533
# Epoch 58/500
# 576/576 [==============================] - 0s 127us/step - loss: 96.8328 - val_loss: 105.7528
#
# Epoch 00058: val_loss did not improve from 105.55533
# Epoch 59/500
# 576/576 [==============================] - 0s 137us/step - loss: 95.3698 - val_loss: 107.3956
#
# Epoch 00059: val_loss did not improve from 105.55533
# Epoch 60/500
# 576/576 [==============================] - 0s 140us/step - loss: 95.0226 - val_loss: 106.8130
#
# Epoch 00060: val_loss did not improve from 105.55533
# Epoch 61/500
# 576/576 [==============================] - 0s 132us/step - loss: 95.9408 - val_loss: 106.3868
#
# Epoch 00061: val_loss did not improve from 105.55533
# Epoch 62/500
# 576/576 [==============================] - 0s 134us/step - loss: 95.4164 - val_loss: 106.4718
#
# Epoch 00062: val_loss did not improve from 105.55533
# Epoch 63/500
# 576/576 [==============================] - 0s 134us/step - loss: 94.2584 - val_loss: 106.3703
#
# Epoch 00063: val_loss did not improve from 105.55533
# Epoch 64/500
# 576/576 [==============================] - 0s 133us/step - loss: 93.7434 - val_loss: 108.1676
#
# Epoch 00064: val_loss did not improve from 105.55533
# Epoch 65/500
# 576/576 [==============================] - 0s 136us/step - loss: 93.7044 - val_loss: 100.4907
#
# Epoch 00065: val_loss improved from 105.55533 to 100.49069, saving model to weights.hdf5
# Epoch 66/500
# 576/576 [==============================] - 0s 115us/step - loss: 93.5197 - val_loss: 104.1025
#
# Epoch 00066: val_loss did not improve from 100.49069
# Epoch 67/500
# 576/576 [==============================] - 0s 123us/step - loss: 91.5904 - val_loss: 101.0992
#
# Epoch 00067: val_loss did not improve from 100.49069
# Epoch 68/500
# 576/576 [==============================] - 0s 130us/step - loss: 93.2182 - val_loss: 103.1735
#
# Epoch 00068: val_loss did not improve from 100.49069
# Epoch 69/500
# 576/576 [==============================] - 0s 136us/step - loss: 92.0116 - val_loss: 101.0753
#
# Epoch 00069: val_loss did not improve from 100.49069
# Epoch 70/500
# 576/576 [==============================] - 0s 134us/step - loss: 90.4405 - val_loss: 100.3007
#
# Epoch 00070: val_loss improved from 100.49069 to 100.30073, saving model to weights.hdf5
# Epoch 71/500
# 576/576 [==============================] - 0s 118us/step - loss: 91.4165 - val_loss: 108.1712
#
# Epoch 00071: val_loss did not improve from 100.30073
# Epoch 72/500
# 576/576 [==============================] - 0s 124us/step - loss: 91.4221 - val_loss: 105.4366
#
# Epoch 00072: val_loss did not improve from 100.30073
# Epoch 73/500
# 576/576 [==============================] - 0s 132us/step - loss: 90.8071 - val_loss: 104.0236
#
# Epoch 00073: val_loss did not improve from 100.30073
# Epoch 74/500
# 576/576 [==============================] - 0s 137us/step - loss: 90.4948 - val_loss: 105.4752
#
# Epoch 00074: val_loss did not improve from 100.30073
# Epoch 75/500
# 576/576 [==============================] - 0s 138us/step - loss: 89.4984 - val_loss: 108.1772
#
# Epoch 00075: val_loss did not improve from 100.30073
# Epoch 76/500
# 576/576 [==============================] - 0s 135us/step - loss: 88.3263 - val_loss: 116.2144
#
# Epoch 00076: val_loss did not improve from 100.30073
# Epoch 77/500
# 576/576 [==============================] - 0s 134us/step - loss: 90.0374 - val_loss: 108.3222
#
# Epoch 00077: val_loss did not improve from 100.30073
# Epoch 78/500
# 576/576 [==============================] - 0s 136us/step - loss: 90.9523 - val_loss: 109.9376
#
# Epoch 00078: val_loss did not improve from 100.30073
# Epoch 79/500
# 576/576 [==============================] - 0s 135us/step - loss: 92.3773 - val_loss: 111.1073
#
# Epoch 00079: val_loss did not improve from 100.30073
# Epoch 80/500
# 576/576 [==============================] - 0s 135us/step - loss: 89.4491 - val_loss: 107.5164
#
# Epoch 00080: val_loss did not improve from 100.30073
# Epoch 81/500
# 576/576 [==============================] - 0s 135us/step - loss: 87.8961 - val_loss: 122.5858
#
# Epoch 00081: val_loss did not improve from 100.30073
# Epoch 82/500
# 576/576 [==============================] - 0s 136us/step - loss: 88.2328 - val_loss: 104.2121
#
# Epoch 00082: val_loss did not improve from 100.30073
# Epoch 83/500
# 576/576 [==============================] - 0s 136us/step - loss: 87.6148 - val_loss: 110.0277
#
# Epoch 00083: val_loss did not improve from 100.30073
# Epoch 84/500
# Epoch 00103: val_loss did not improve from 100.30073
# Epoch 104/500
# 576/576 [==============================] - 0s 137us/step - loss: 81.4688 - val_loss: 119.2576
#
# Epoch 00104: val_loss did not improve from 100.30073
# Epoch 105/500
# 576/576 [==============================] - 0s 135us/step - loss: 82.4223 - val_loss: 107.0925
#
# Epoch 00105: val_loss did not improve from 100.30073
# Epoch 106/500
# 576/576 [==============================] - 0s 138us/step - loss: 81.7676 - val_loss: 103.1140
#
# Epoch 00106: val_loss did not improve from 100.30073
# Epoch 107/500
# 576/576 [==============================] - 0s 136us/step - loss: 80.2163 - val_loss: 111.1793
#
# Epoch 00107: val_loss did not improve from 100.30073
# Epoch 108/500
# 576/576 [==============================] - 0s 136us/step - loss: 79.8999 - val_loss: 111.3318
#
# Epoch 00108: val_loss did not improve from 100.30073
# Epoch 109/500
# 576/576 [==============================] - 0s 135us/step - loss: 80.7328 - val_loss: 120.8761
#
# Epoch 00109: val_loss did not improve from 100.30073
# Epoch 110/500
# 576/576 [==============================] - 0s 138us/step - loss: 80.5662 - val_loss: 116.9974
#
# Epoch 00110: val_loss did not improve from 100.30073
# Epoch 111/500
# 576/576 [==============================] - 0s 136us/step - loss: 81.0883 - val_loss: 120.0144
#
# Epoch 00111: val_loss did not improve from 100.30073
# Epoch 112/500
# 576/576 [==============================] - 0s 135us/step - loss: 80.2623 - val_loss: 113.6120
#
# Epoch 00112: val_loss did not improve from 100.30073
# Epoch 113/500
# 576/576 [==============================] - 0s 136us/step - loss: 81.6402 - val_loss: 115.9799
#
# Epoch 00113: val_loss did not improve from 100.30073
# Epoch 114/500
# 576/576 [==============================] - 0s 134us/step - loss: 78.7589 - val_loss: 124.2764
#
# Epoch 00114: val_loss did not improve from 100.30073
# Epoch 115/500
# 576/576 [==============================] - 0s 137us/step - loss: 77.4772 - val_loss: 117.4891
#
# Epoch 00115: val_loss did not improve from 100.30073
# Epoch 116/500
# 576/576 [==============================] - 0s 137us/step - loss: 80.0123 - val_loss: 124.4493
#
# Epoch 00116: val_loss did not improve from 100.30073
# Epoch 117/500
# 576/576 [==============================] - 0s 135us/step - loss: 78.8130 - val_loss: 124.4562
#
# Epoch 00117: val_loss did not improve from 100.30073
# Epoch 118/500
# 576/576 [==============================] - 0s 134us/step - loss: 77.5619 - val_loss: 107.8295
#
# Epoch 00118: val_loss did not improve from 100.30073
# Epoch 119/500
# 576/576 [==============================] - 0s 137us/step - loss: 77.2985 - val_loss: 118.6059
#
# Epoch 00119: val_loss did not improve from 100.30073
# Epoch 120/500
# 576/576 [==============================] - 0s 139us/step - loss: 77.7902 - val_loss: 113.9097
#
# Epoch 00120: val_loss did not improve from 100.30073
# Epoch 121/500
# 576/576 [==============================] - 0s 138us/step - loss: 78.2477 - val_loss: 115.7618
#
# Epoch 00121: val_loss did not improve from 100.30073
# Epoch 122/500
# 576/576 [==============================] - 0s 137us/step - loss: 78.3210 - val_loss: 98.8698
#
# Epoch 00122: val_loss improved from 100.30073 to 98.86980, saving model to weights.hdf5
# Epoch 123/500
# 576/576 [==============================] - 0s 141us/step - loss: 45.9026 - val_loss: 153.1191
#
# Epoch 00488: val_loss did not improve from 92.43546
# Epoch 489/500
# 576/576 [==============================] - 0s 138us/step - loss: 46.4260 - val_loss: 157.5556
#
# Epoch 00489: val_loss did not improve from 92.43546
# Epoch 490/500
# 576/576 [==============================] - 0s 137us/step - loss: 45.9254 - val_loss: 156.8925
#
# Epoch 00490: val_loss did not improve from 92.43546
# Epoch 491/500
# 576/576 [==============================] - 0s 133us/step - loss: 45.2403 - val_loss: 170.5252
#
# Epoch 00491: val_loss did not improve from 92.43546
# Epoch 492/500
# 576/576 [==============================] - 0s 146us/step - loss: 47.2250 - val_loss: 144.4377
#
# Epoch 00492: val_loss did not improve from 92.43546
# Epoch 493/500
# 576/576 [==============================] - 0s 138us/step - loss: 46.3619 - val_loss: 157.8253
#
# Epoch 00493: val_loss did not improve from 92.43546
# Epoch 494/500
# 576/576 [==============================] - 0s 138us/step - loss: 44.5196 - val_loss: 154.1229
#
# Epoch 00494: val_loss did not improve from 92.43546
# Epoch 495/500
# 576/576 [==============================] - 0s 137us/step - loss: 46.9502 - val_loss: 141.0925
#
# Epoch 00495: val_loss did not improve from 92.43546
# Epoch 496/500
# 576/576 [==============================] - 0s 139us/step - loss: 46.1488 - val_loss: 158.8239
#
# Epoch 00496: val_loss did not improve from 92.43546
# Epoch 497/500
# 576/576 [==============================] - 0s 137us/step - loss: 45.5789 - val_loss: 151.5637
#
# Epoch 00497: val_loss did not improve from 92.43546
# Epoch 498/500
# 576/576 [==============================] - 0s 138us/step - loss: 45.3823 - val_loss: 134.6652
#
# Epoch 00498: val_loss did not improve from 92.43546
# Epoch 499/500
# 576/576 [==============================] - 0s 138us/step - loss: 44.1240 - val_loss: 135.1211
#
# Epoch 00499: val_loss did not improve from 92.43546
# Epoch 500/500
# 576/576 [==============================] - 0s 138us/step - loss: 42.9393 - val_loss: 146.4315
#
# Epoch 00500: val_loss did not improve from 92.43546

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input: 0':x_train})

# %%
z_m_m = np.mean(z_output,axis=0)
z_m_m
# Out:
# array([-0.25983194, -0.11042119, -0.05936022,  0.05178137], dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 1.00173921e+00,  5.07581361e-09,  1.51973642e-08,
#          8.23179494e-08],
#        [ 5.07581361e-09,  1.00173924e+00,  1.61635818e-08,
#          9.50606681e-09],
#        [ 1.51973642e-08,  1.61635818e-08,  1.00173924e+00,
#         -3.77420286e-09],
#        [ 8.23179494e-08,  9.50606681e-09, -3.77420286e-09,
#          1.00173899e+00]])

# %% [markdown]
# Plot the Pearson correlation among Z

# %%
plt.matshow(np.corrcoef(z_output.T))

# %%
z_m_m
# Out:
# array([-0.25983194, -0.11042119, -0.05936022,  0.05178137], dtype=float32)

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
