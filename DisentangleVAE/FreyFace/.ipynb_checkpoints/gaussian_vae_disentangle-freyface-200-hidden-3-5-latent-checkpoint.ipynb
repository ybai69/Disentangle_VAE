# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from keras.layers import Lambda, Input, Dense
from keras.models import Model
from keras.datasets import mnist
from keras.losses import mse, binary_crossentropy
from keras.utils import plot_model
from keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import argparse
import os
# Out:
# Using TensorFlow backend.

# %%
from urllib.error import URLError, HTTPError
from urllib.request import urlopen
from scipy.io import loadmat


def fetch_file(url):
    """Downloads a file from a URL.
    """
    try:
        f = urlopen(url)
        print("Downloading data file " + url + " ...")

        # Open our local file for writing
        with open(os.path.basename(url), "wb") as local_file:
            local_file.write(f.read())
        print("Done.")

    #handle errors
    except HTTPError as e:
        print("HTTP Error:", e.code, url)
    except URLError as e:
        print("URL Error:", e.reason, url) 
        
url =  "http://www.cs.nyu.edu/~roweis/data/frey_rawface.mat"
data_filename = os.path.basename(url)
if not os.path.exists(data_filename):
    fetch_file(url)
else:
    print("Data file %s exists." % data_filename) 
    
# reshape data for later convenience
img_rows, img_cols = 28, 20
ff = loadmat(data_filename, squeeze_me=True, struct_as_record=False)
ff = ff["ff"].T.reshape((-1, img_rows, img_cols))
# Out:
# Data file frey_rawface.mat exists.

# %%
# split data into train / validation folds
np.random.seed(42)
n_pixels = img_rows * img_cols
x_train = ff[:1800]
x_test = ff[1800:1900]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), n_pixels))
x_test = x_test.reshape((len(x_test), n_pixels))

# %%
def show_examples(data, n=None, n_cols=20, thumbnail_cb=None):
    if n is None:
        n = len(data)    
    n_rows = int(np.ceil(n / float(n_cols)))
    figure = np.zeros((img_rows * n_rows, img_cols * n_cols))
    for k, x in enumerate(data[:n]):
        r = k // n_cols
        c = k % n_cols
        figure[r * img_rows: (r + 1) * img_rows,
               c * img_cols: (c + 1) * img_cols] = x
        if thumbnail_cb is not None:
            thumbnail_cb(locals())
        
    plt.figure(figsize=(12, 10))
    plt.imshow(figure)
    plt.axis("off")
    plt.tight_layout()
show_examples(ff, n=500, n_cols=25)

# %%
import tensorflow as tf
sess = tf.Session()

K.set_session(sess)

# %%
def sampling(args):
    """Reparameterization trick by sampling fr an isotropic unit Gaussian.

    # Arguments:
        args (tensor): mean and log of variance of Q(z|X)

    # Returns:
        z (tensor): sampled latent vector
    """

    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon
#     return z_mean + K.exp(0.5 ) * epsilon

# %%
def plot_results(models,
                 latent_dim,
                 latent_num,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):
    """Plots labels and MNIST digits as function of 2-dim latent vector

    # Arguments:
        models (tuple): encoder and decoder models
        data (tuple): test data and label
        batch_size (int): prediction batch size
        model_name (string): which model is using this function
    """

    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)

    
    
    """filename = os.path.join(model_name, "vae_mean.png")
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = encoder.predict(x_test,
                                   batch_size=batch_size)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=y_test)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.savefig(filename)
    plt.show()
    """

    #filename = os.path.join(model_name, "face_over_latent.png")
    n = 20
    digit_size = 28
    img_rows, img_cols = 28, 20
    figure = np.zeros((img_rows , img_cols * n))
    grid_x = np.linspace(-5, 5, n)
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
    z_sample[0,:] = z_m_m 
    
    for j, xi in enumerate(grid_x):
        z_sample[0,latent_num] = z_m_m[latent_num] + xi
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(img_rows, img_cols)
        figure[0: img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    #plt.savefig(filename)
    plt.show()

# %%
from random import *
def plot_random_results(models,
                 latent_dim,
                 z_m_m, 
                 batch_size=128,
                 model_name="vae_face"):


    encoder, decoder = models
    #x_test = data
    latent_dim = latent_dim
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "face_over_latent.png")
    n = 10
    digit_size = 28
    img_rows, img_cols = 28, 20
    figure = np.zeros((img_rows * n , img_cols * n))
    
    #grid_x = np.linspace(-5, 5, n)
    #grid_y = np.linspace(-5, 5, n)[::-1]
    z_sample = np.zeros((1,latent_dim))
     
    
    for j in range(n):
        for k in range(n):
            z_sample[0,:] = z_m_m
            l = [x * 2 for x in [uniform(-1,1) for i in range(latent_dim)]]
            z_sample[0,:] += l
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(img_rows, img_cols)
            figure[k * img_rows : (k+1) * img_rows,j * img_cols: (j + 1) * img_cols] = digit

    plt.figure(figsize=(20, 20))
    #start_range = digit_size // 2
    #end_range = n * digit_size + start_range + 1
    #pixel_range = np.arange(start_range, end_range, digit_size)
    #sample_range_x = np.round(grid_x, 1)
    #sample_range_y = np.round(grid_y, 1)
    #plt.xticks(pixel_range, sample_range_x)
    #plt.yticks(pixel_range, sample_range_y)
    #plt.xlabel("z[0]")
    #plt.ylabel("z[1]")
    plt.axis('off')
    plt.imshow(figure, cmap='gray')
    plt.savefig(filename)
    plt.show()

# %%
[uniform(-1,1) for i in range(5)]
# Out:
# [0.6644822245668449,
#  0.32675662090719504,
#  -0.6671654479422149,
#  -0.9249907038689533,
#  0.513363440457919]

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 3
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e89b090f25d> in <module>
#       1 # VAE model = encoder + decoder
#       2 # build encoder model
# ----> 3 inputs = Input(shape=input_shape, name='encoder_input')
#       4 x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#       5 #x2 = Dense(intermediate_dim2, activation='relu')(x1)
#
# NameError: name 'Input' is not defined

# %%
# standardize the mean of z, so that mean(m_z)=0 and cov(m_z)=I
def standardize(z_mean):
    z_m_m = K.mean(z_mean,axis=0, keepdims=True)
    z1 = z_mean - z_m_m
    n = tf.cast(K.shape(z_mean)[0], tf.float32)
    cov = K.transpose(z1) @ z1 /n
    
    D = tf.diag(tf.diag_part(cov)) ** 0.5J
    
    L = tf.linalg.inv(tf.transpose(tf.cholesky(cov)))
       
#     z2 = z1 @ L @ D +  z_m_m
    z2 = z1 @ L  +  z_m_m

    return( z2)

# %%
z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 560)          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          112200      encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 3)            603         dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 3)            603         dense_1[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 3)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 113,406
# Trainable params: 113,406
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               800
# _________________________________________________________________
# dense_3 (Dense)              (None, 560)               112560
# =================================================================
# Total params: 113,360
# Trainable params: 113,360
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 560)               0
# _________________________________________________________________
# encoder (Model)              [(None, 3), (None, 3), (N 113406
# _________________________________________________________________
# decoder (Model)              (None, 560)               113360
# =================================================================
# Total params: 226,766
# Trainable params: 226,766
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 1800 samples, validate on 100 samples
# Epoch 1/100
# 1800/1800 [==============================] - 1s 334us/step - loss: 381.5587 - val_loss: 372.1600
# Epoch 2/100
# 1800/1800 [==============================] - 0s 51us/step - loss: 363.5194 - val_loss: 363.4965
# Epoch 3/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 356.6602 - val_loss: 360.9809
# Epoch 4/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 354.7713 - val_loss: 360.7779
# Epoch 5/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 354.5103 - val_loss: 360.0595
# Epoch 6/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 353.6755 - val_loss: 359.6048
# Epoch 7/100
# 1800/1800 [==============================] - 0s 56us/step - loss: 353.4941 - val_loss: 359.4845
# Epoch 8/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 353.3219 - val_loss: 359.6891
# Epoch 9/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 352.8829 - val_loss: 361.1755
# Epoch 10/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 352.8499 - val_loss: 359.6638
# Epoch 11/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 352.0273 - val_loss: 358.3382
# Epoch 12/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 351.5928 - val_loss: 358.1003
# Epoch 13/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 351.0344 - val_loss: 357.6128
# Epoch 14/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 350.8375 - val_loss: 357.0786
# Epoch 15/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 350.5152 - val_loss: 356.6355
# Epoch 16/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 350.3497 - val_loss: 355.8141
# Epoch 17/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 350.0924 - val_loss: 356.7323
# Epoch 18/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 350.0066 - val_loss: 355.8679
# Epoch 19/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.9604 - val_loss: 355.7227
# Epoch 20/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.9181 - val_loss: 355.9005
# Epoch 21/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.7748 - val_loss: 355.7187
# Epoch 22/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.6976 - val_loss: 355.9252
# Epoch 23/100
# 1800/1800 [==============================] - 0s 56us/step - loss: 349.7305 - val_loss: 355.7523
# Epoch 24/100
# 1800/1800 [==============================] - 0s 56us/step - loss: 349.6105 - val_loss: 355.3883
# Epoch 25/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 349.5716 - val_loss: 355.3015
# Epoch 26/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.4787 - val_loss: 355.0389
# Epoch 27/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.4343 - val_loss: 355.1210
# Epoch 28/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 349.4576 - val_loss: 354.7993
# Epoch 29/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.3421 - val_loss: 355.4330
# Epoch 30/100
# 1800/1800 [==============================] - 0s 56us/step - loss: 349.4008 - val_loss: 354.8896
# Epoch 31/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 349.1868 - val_loss: 354.4858
# Epoch 32/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 349.1176 - val_loss: 354.4139
# Epoch 33/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.0888 - val_loss: 354.0644
# Epoch 34/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.9494 - val_loss: 353.5101
# Epoch 35/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.8016 - val_loss: 353.4432
# Epoch 36/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.7780 - val_loss: 353.2809
# Epoch 37/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.6380 - val_loss: 353.3532
# Epoch 38/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.6651 - val_loss: 353.5484
# Epoch 39/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.6007 - val_loss: 353.2125
# Epoch 40/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.5558 - val_loss: 353.9805
# Epoch 41/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.6783 - val_loss: 353.3550
# Epoch 42/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.5100 - val_loss: 353.3873
# Epoch 43/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.4966 - val_loss: 353.0640
# Epoch 44/100
# 1800/1800 [==============================] - 0s 51us/step - loss: 348.4823 - val_loss: 353.4295
# Epoch 45/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.3718 - val_loss: 353.1520
# Epoch 46/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.3835 - val_loss: 353.5668
# Epoch 47/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.3778 - val_loss: 353.8491
# Epoch 48/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.4038 - val_loss: 353.8422
# Epoch 49/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.4734 - val_loss: 353.3121
# Epoch 50/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.3553 - val_loss: 353.7193
# Epoch 51/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.3322 - val_loss: 353.1942
# Epoch 52/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.2699 - val_loss: 353.4174
# Epoch 53/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.2287 - val_loss: 353.2176
# Epoch 54/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.1836 - val_loss: 353.2764
# Epoch 55/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.2572 - val_loss: 353.5392
# Epoch 56/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.2012 - val_loss: 353.3194
# Epoch 57/100
# 1800/1800 [==============================] - 0s 56us/step - loss: 348.1852 - val_loss: 353.8083
# Epoch 58/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.1559 - val_loss: 353.1708
# Epoch 59/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.1561 - val_loss: 353.1649
# Epoch 60/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.1513 - val_loss: 353.6028
# Epoch 61/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.1671 - val_loss: 353.5526
# Epoch 62/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1188 - val_loss: 353.0637
# Epoch 63/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.0196 - val_loss: 353.1183
# Epoch 64/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.0314 - val_loss: 353.3820
# Epoch 65/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9998 - val_loss: 353.2929
# Epoch 66/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.0175 - val_loss: 353.2691
# Epoch 67/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0131 - val_loss: 353.8365
# Epoch 68/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.0731 - val_loss: 353.0947
# Epoch 69/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.9816 - val_loss: 353.4899
# Epoch 70/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.0612 - val_loss: 353.3438
# Epoch 71/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.9252 - val_loss: 353.3705
# Epoch 72/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9770 - val_loss: 353.4606
# Epoch 73/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9543 - val_loss: 353.1955
# Epoch 74/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9544 - val_loss: 353.0385
# Epoch 75/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9820 - val_loss: 353.1439
# Epoch 76/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9268 - val_loss: 353.0711
# Epoch 77/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9367 - val_loss: 352.9809
# Epoch 78/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.9652 - val_loss: 353.2675
# Epoch 79/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.9195 - val_loss: 353.2500
# Epoch 80/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.9637 - val_loss: 353.4422
# Epoch 81/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9161 - val_loss: 353.3547
# Epoch 82/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8452 - val_loss: 352.9410
# Epoch 83/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.8356 - val_loss: 353.3490
# Epoch 84/100
# 1800/1800 [==============================] - 0s 52us/step - loss: 347.8510 - val_loss: 353.2890
# Epoch 85/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8570 - val_loss: 353.6922
# Epoch 86/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.9173 - val_loss: 353.4845
# Epoch 87/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9112 - val_loss: 353.3564
# Epoch 88/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8693 - val_loss: 353.1629
# Epoch 89/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.7957 - val_loss: 353.2330
# Epoch 90/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.8159 - val_loss: 353.3477
# Epoch 91/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.8777 - val_loss: 353.2928
# Epoch 92/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8386 - val_loss: 354.0268
# Epoch 93/100
# 1800/1800 [==============================] - 0s 56us/step - loss: 347.8322 - val_loss: 353.2564
# Epoch 94/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 347.7699 - val_loss: 353.2907
# Epoch 95/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.7758 - val_loss: 353.5865
# Epoch 96/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.7937 - val_loss: 353.3406
# Epoch 97/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.7728 - val_loss: 353.2628
# Epoch 98/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.7223 - val_loss: 353.3396
# Epoch 99/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.7527 - val_loss: 353.3419
# Epoch 100/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.7873 - val_loss: 353.5307

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input:0':x_test})

z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
np.zeros((1, 2 )) 
print(z_m_m)

np.cov(z_output.T)
# Out:
# [-0.7635347  -1.4436471   0.99946785]
# array([[ 0.17779731,  0.12286625, -0.08880738],
#        [ 0.12286625,  0.25716847, -0.03840102],
#        [-0.08880738, -0.03840102,  0.08736143]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")

# %%
'''
plot_random_results(models,
                 latent_dim,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
'''
# Out:
# '\nplot_random_results(models,\n                 latent_dim,\n                 z_m_m = z_m_m ,\n                 batch_size=batch_size,\n                 model_name="vae_mlp")\n'

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 4
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input_1')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 4)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 200)               1000
# _________________________________________________________________
# dense_6 (Dense)              (None, 560)               112560
# =================================================================
# Total params: 113,560
# Trainable params: 113,560
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input_1 (InputLayer) (None, 560)               0
# _________________________________________________________________
# encoder (Model)              [(None, 4), (None, 4), (N 113808
# _________________________________________________________________
# decoder (Model)              (None, 560)               113560
# =================================================================
# Total params: 227,368
# Trainable params: 227,368
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 1800 samples, validate on 100 samples
# Epoch 1/100
# 1800/1800 [==============================] - 0s 212us/step - loss: 381.2557 - val_loss: 371.7914
# Epoch 2/100
# 1800/1800 [==============================] - 0s 52us/step - loss: 363.3459 - val_loss: 362.5762
# Epoch 3/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 356.8077 - val_loss: 361.2682
# Epoch 4/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 355.1090 - val_loss: 362.1502
# Epoch 5/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 354.6518 - val_loss: 359.8661
# Epoch 6/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 354.2609 - val_loss: 360.0623
# Epoch 7/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 353.7022 - val_loss: 359.4897
# Epoch 8/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 353.3258 - val_loss: 358.6854
# Epoch 9/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 352.9061 - val_loss: 358.4690
# Epoch 10/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 352.2648 - val_loss: 356.4559
# Epoch 11/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 351.7103 - val_loss: 356.7306
# Epoch 12/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 351.1276 - val_loss: 355.6959
# Epoch 13/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 350.9008 - val_loss: 355.1620
# Epoch 14/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 350.5757 - val_loss: 355.8086
# Epoch 15/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 350.3665 - val_loss: 355.1489
# Epoch 16/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 350.1772 - val_loss: 355.1923
# Epoch 17/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 350.0345 - val_loss: 355.3593
# Epoch 18/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 350.1064 - val_loss: 355.2836
# Epoch 19/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.8694 - val_loss: 355.1349
# Epoch 20/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 349.7885 - val_loss: 355.2666
# Epoch 21/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 349.7781 - val_loss: 355.2616
# Epoch 22/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 349.7511 - val_loss: 355.1286
# Epoch 23/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.6357 - val_loss: 354.8919
# Epoch 24/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.6128 - val_loss: 354.6715
# Epoch 25/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 349.5340 - val_loss: 355.2703
# Epoch 26/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.5055 - val_loss: 354.5491
# Epoch 27/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.3854 - val_loss: 354.3919
# Epoch 28/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.4185 - val_loss: 354.3220
# Epoch 29/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.3069 - val_loss: 353.8066
# Epoch 30/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.3222 - val_loss: 354.1085
# Epoch 31/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.2573 - val_loss: 354.4586
# Epoch 32/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.1172 - val_loss: 353.8269
# Epoch 33/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.9281 - val_loss: 353.6554
# Epoch 34/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.8763 - val_loss: 353.5091
# Epoch 35/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.9324 - val_loss: 353.2968
# Epoch 36/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.7826 - val_loss: 353.5807
# Epoch 37/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.7000 - val_loss: 353.2550
# Epoch 38/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.7092 - val_loss: 353.5577
# Epoch 39/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.6610 - val_loss: 353.9087
# Epoch 40/100
# 1800/1800 [==============================] - 0s 63us/step - loss: 348.6755 - val_loss: 353.5503
# Epoch 41/100
# 1800/1800 [==============================] - 0s 52us/step - loss: 348.6738 - val_loss: 353.4592
# Epoch 42/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.5424 - val_loss: 353.3564
# Epoch 43/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.5064 - val_loss: 353.5507
# Epoch 44/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.5480 - val_loss: 353.7294
# Epoch 45/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.5205 - val_loss: 353.2018
# Epoch 46/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.4221 - val_loss: 353.2914
# Epoch 47/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.3347 - val_loss: 353.2569
# Epoch 48/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.3468 - val_loss: 353.1447
# Epoch 49/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.3262 - val_loss: 353.4968
# Epoch 50/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.2870 - val_loss: 353.3943
# Epoch 51/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.4599 - val_loss: 353.3488
# Epoch 52/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.2716 - val_loss: 353.3114
# Epoch 53/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.2395 - val_loss: 353.2578
# Epoch 54/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.2316 - val_loss: 353.8083
# Epoch 55/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.2730 - val_loss: 353.3241
# Epoch 56/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.2864 - val_loss: 353.6042
# Epoch 57/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.2347 - val_loss: 353.2498
# Epoch 58/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.1198 - val_loss: 353.4013
# Epoch 59/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1502 - val_loss: 353.1323
# Epoch 60/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.2662 - val_loss: 353.4471
# Epoch 61/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0415 - val_loss: 353.2948
# Epoch 62/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1087 - val_loss: 353.5197
# Epoch 63/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0852 - val_loss: 353.3791
# Epoch 64/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0606 - val_loss: 353.0099
# Epoch 65/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.0568 - val_loss: 353.1354
# Epoch 66/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0372 - val_loss: 353.2533
# Epoch 67/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1348 - val_loss: 353.3284
# Epoch 68/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0710 - val_loss: 352.9043
# Epoch 69/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9751 - val_loss: 353.4209
# Epoch 70/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0562 - val_loss: 353.4839
# Epoch 71/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.9852 - val_loss: 353.3484
# Epoch 72/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0788 - val_loss: 353.4066
# Epoch 73/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.0252 - val_loss: 353.4258
# Epoch 74/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0348 - val_loss: 353.6022
# Epoch 75/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0422 - val_loss: 353.2005
# Epoch 76/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0388 - val_loss: 353.2613
# Epoch 77/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9855 - val_loss: 353.5363
# Epoch 78/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9450 - val_loss: 353.0355
# Epoch 79/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.0465 - val_loss: 353.4919
# Epoch 80/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.0531 - val_loss: 353.5335
# Epoch 81/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0189 - val_loss: 352.9995
# Epoch 82/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9298 - val_loss: 353.9336
# Epoch 83/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.9354 - val_loss: 353.2451
# Epoch 84/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8783 - val_loss: 353.5291
# Epoch 85/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8600 - val_loss: 353.5016
# Epoch 86/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.9280 - val_loss: 353.1328
# Epoch 87/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.9809 - val_loss: 353.3736
# Epoch 88/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.8977 - val_loss: 353.1122
# Epoch 89/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.8958 - val_loss: 354.4304
# Epoch 90/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1025 - val_loss: 353.2950
# Epoch 91/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0241 - val_loss: 354.2728
# Epoch 92/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0691 - val_loss: 352.9329
# Epoch 93/100
# 1800/1800 [==============================] - 0s 61us/step - loss: 347.8650 - val_loss: 353.2360
# Epoch 94/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8394 - val_loss: 353.2775
# Epoch 95/100
# 1800/1800 [==============================] - 0s 52us/step - loss: 347.8267 - val_loss: 353.4026
# Epoch 96/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8458 - val_loss: 353.0187
# Epoch 97/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.7693 - val_loss: 353.6119
# Epoch 98/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8410 - val_loss: 353.3204
# Epoch 99/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.7650 - val_loss: 353.9761
# Epoch 100/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.9740 - val_loss: 353.0212

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input_1:0':x_test})
z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
np.zeros((1, 2 )) 
z_m_m
# Out:
# array([-0.78488344, -1.1946051 , -0.22183652,  0.5874328 ], dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 0.10910766,  0.04875678, -0.03457384, -0.08998648],
#        [ 0.04875678,  0.2504065 ,  0.0635754 , -0.13112384],
#        [-0.03457384,  0.0635754 ,  0.05984276, -0.01388188],
#        [-0.08998648, -0.13112384, -0.01388188,  0.17232287]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")

# %%
# network parameters
original_dim = n_pixels
input_shape = (original_dim, )
intermediate_dim1 = 200
#intermediate_dim2 = 64
#intermediate_dim3 = 16

batch_size = 128
latent_dim = 5
epochs = 100

# %%
# VAE model = encoder + decoder
# build encoder model
inputs = Input(shape=input_shape, name='encoder_input_2')
x1 = Dense(intermediate_dim1, activation='relu')(inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x1)
#x3 = Dense(intermediate_dim3, activation='relu')(x2)

z_mean = Dense(latent_dim, name='z_mean')(x1)
z_log_var = Dense(latent_dim, name='z_log_var')(x1)

# %%
z_mean_std = Lambda(standardize, output_shape=(latent_dim,), name='z_mean_std')(z_mean)

# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean_std, z_log_var])

# instantiate encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_2 (InputLayer)    (None, 560)          0
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 200)          112200      encoder_input_2[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 5)            1005        dense_7[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 5)            1005        dense_7[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 5)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 114,210
# Trainable params: 114,210
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build decoder model
latent_inputs = Input(shape=(latent_dim,), name='z_sampling')

#x3 = Dense(intermediate_dim3, activation='relu')(latent_inputs)
#x2 = Dense(intermediate_dim2, activation='relu')(x3)
x1 = Dense(intermediate_dim1, activation='relu')(latent_inputs)

# x = Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = Dense(original_dim, activation='sigmoid')(x1)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      (None, 5)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               1200
# _________________________________________________________________
# dense_9 (Dense)              (None, 560)               112560
# =================================================================
# Total params: 113,760
# Trainable params: 113,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = Model(inputs, outputs, name='vae_mlp')

# %%
models = (encoder, decoder)
data = (x_test )

# VAE loss = mse_loss or xent_loss + kl_loss

#     reconstruction_loss = mse(inputs, outputs)
reconstruction_loss = binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= original_dim
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input_2 (InputLayer) (None, 560)               0
# _________________________________________________________________
# encoder (Model)              [(None, 5), (None, 5), (N 114210
# _________________________________________________________________
# decoder (Model)              (None, 560)               113760
# =================================================================
# Total params: 227,970
# Trainable params: 227,970
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.fit(x_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# Train on 1800 samples, validate on 100 samples
# Epoch 1/100
# 1800/1800 [==============================] - 0s 252us/step - loss: 380.7755 - val_loss: 370.1953
# Epoch 2/100
# 1800/1800 [==============================] - 0s 54us/step - loss: 362.2553 - val_loss: 362.7969
# Epoch 3/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 356.8333 - val_loss: 361.0603
# Epoch 4/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 355.1744 - val_loss: 361.0983
# Epoch 5/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 354.9002 - val_loss: 359.5579
# Epoch 6/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 354.2102 - val_loss: 359.4096
# Epoch 7/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 353.8314 - val_loss: 359.2455
# Epoch 8/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 353.5958 - val_loss: 357.3035
# Epoch 9/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 352.8438 - val_loss: 355.9301
# Epoch 10/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 352.2264 - val_loss: 355.7796
# Epoch 11/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 351.7022 - val_loss: 355.6112
# Epoch 12/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 351.2874 - val_loss: 355.0592
# Epoch 13/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 350.8845 - val_loss: 355.3301
# Epoch 14/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 350.6389 - val_loss: 355.5207
# Epoch 15/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 350.4817 - val_loss: 355.4698
# Epoch 16/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 350.3100 - val_loss: 355.4466
# Epoch 17/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 350.1928 - val_loss: 354.7375
# Epoch 18/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 350.0949 - val_loss: 354.9753
# Epoch 19/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 349.9257 - val_loss: 354.4679
# Epoch 20/100
# 1800/1800 [==============================] - 0s 61us/step - loss: 349.8533 - val_loss: 354.4608
# Epoch 21/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 349.7411 - val_loss: 354.3552
# Epoch 22/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.4989 - val_loss: 354.4550
# Epoch 23/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.4238 - val_loss: 354.0219
# Epoch 24/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.3097 - val_loss: 354.0331
# Epoch 25/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 349.1267 - val_loss: 353.7768
# Epoch 26/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 349.1889 - val_loss: 353.6575
# Epoch 27/100
# 1800/1800 [==============================] - 0s 61us/step - loss: 349.0407 - val_loss: 353.6020
# Epoch 28/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.9717 - val_loss: 353.4758
# Epoch 29/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.9529 - val_loss: 353.4257
# Epoch 30/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.8558 - val_loss: 353.6664
# Epoch 31/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.8123 - val_loss: 353.9214
# Epoch 32/100
# 1800/1800 [==============================] - 0s 62us/step - loss: 348.8859 - val_loss: 353.6450
# Epoch 33/100
# 1800/1800 [==============================] - 0s 53us/step - loss: 348.6998 - val_loss: 353.4318
# Epoch 34/100
# 1800/1800 [==============================] - 0s 57us/step - loss: 348.6310 - val_loss: 353.5441
# Epoch 35/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.6310 - val_loss: 353.3732
# Epoch 36/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.5232 - val_loss: 353.5303
# Epoch 37/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.5868 - val_loss: 353.8273
# Epoch 38/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.5852 - val_loss: 353.1355
# Epoch 39/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.4939 - val_loss: 353.1537
# Epoch 40/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.5163 - val_loss: 353.2583
# Epoch 41/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.4603 - val_loss: 353.3207
# Epoch 42/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.4982 - val_loss: 353.3607
# Epoch 43/100
# 1800/1800 [==============================] - 0s 61us/step - loss: 348.4578 - val_loss: 352.8112
# Epoch 44/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.3369 - val_loss: 353.2651
# Epoch 45/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.3443 - val_loss: 353.2816
# Epoch 46/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.3002 - val_loss: 353.1729
# Epoch 47/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.2787 - val_loss: 353.5157
# Epoch 48/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.2377 - val_loss: 353.1213
# Epoch 49/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.2396 - val_loss: 353.3730
# Epoch 50/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.2772 - val_loss: 353.5691
# Epoch 51/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.2602 - val_loss: 353.4998
# Epoch 52/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1847 - val_loss: 353.0001
# Epoch 53/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.1591 - val_loss: 353.2350
# Epoch 54/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.2030 - val_loss: 352.6953
# Epoch 55/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1997 - val_loss: 353.2665
# Epoch 56/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.1120 - val_loss: 353.3116
# Epoch 57/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 348.2520 - val_loss: 352.8763
# Epoch 58/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.1294 - val_loss: 352.9799
# Epoch 59/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0872 - val_loss: 353.5783
# Epoch 60/100
# 1800/1800 [==============================] - 0s 61us/step - loss: 348.2796 - val_loss: 353.0937
# Epoch 61/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0550 - val_loss: 353.0288
# Epoch 62/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0477 - val_loss: 353.2532
# Epoch 63/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0432 - val_loss: 353.1794
# Epoch 64/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9688 - val_loss: 353.1079
# Epoch 65/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0039 - val_loss: 352.6064
# Epoch 66/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.9462 - val_loss: 353.1201
# Epoch 67/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 348.0810 - val_loss: 353.0572
# Epoch 68/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9576 - val_loss: 353.2681
# Epoch 69/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9953 - val_loss: 353.0834
# Epoch 70/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.9982 - val_loss: 352.9912
# Epoch 71/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9557 - val_loss: 352.7846
# Epoch 72/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9449 - val_loss: 353.4608
# Epoch 73/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0228 - val_loss: 353.1789
# Epoch 74/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.8804 - val_loss: 353.6479
# Epoch 75/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9876 - val_loss: 352.8196
# Epoch 76/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9195 - val_loss: 353.2465
# Epoch 77/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 348.0070 - val_loss: 352.8588
# Epoch 78/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8856 - val_loss: 353.1293
# Epoch 79/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8282 - val_loss: 353.5360
# Epoch 80/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9517 - val_loss: 352.8673
# Epoch 81/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.9396 - val_loss: 353.4544
# Epoch 82/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.9144 - val_loss: 353.0161
# Epoch 83/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8310 - val_loss: 352.9671
# Epoch 84/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8784 - val_loss: 353.3007
# Epoch 85/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.7774 - val_loss: 352.9559
# Epoch 86/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.7594 - val_loss: 353.2137
# Epoch 87/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8135 - val_loss: 352.8671
# Epoch 88/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.8557 - val_loss: 353.3017
# Epoch 89/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8603 - val_loss: 353.2026
# Epoch 90/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.7075 - val_loss: 352.7763
# Epoch 91/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.8039 - val_loss: 353.2475
# Epoch 92/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.8918 - val_loss: 353.2390
# Epoch 93/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.7083 - val_loss: 352.8251
# Epoch 94/100
# 1800/1800 [==============================] - 0s 61us/step - loss: 347.7550 - val_loss: 353.1148
# Epoch 95/100
# 1800/1800 [==============================] - 0s 60us/step - loss: 347.7321 - val_loss: 353.4857
# Epoch 96/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.7473 - val_loss: 353.6773
# Epoch 97/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8460 - val_loss: 353.0419
# Epoch 98/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.7088 - val_loss: 353.0854
# Epoch 99/100
# 1800/1800 [==============================] - 0s 59us/step - loss: 347.6866 - val_loss: 352.7511
# Epoch 100/100
# 1800/1800 [==============================] - 0s 58us/step - loss: 347.8349 - val_loss: 353.5209

# %%
z_output = sess.run( z_mean_std, feed_dict={'encoder_input_2:0':x_test})
z_m_m = np.mean(z_output,axis=0)
z_m_m
#z_m_m[1]
#type(z_m_m)
#np.zeros((1, 2 )) 
z_m_m
# Out:
# array([-0.06488406, -0.6363964 ,  0.17165525,  1.452659  , -1.058426  ],
#       dtype=float32)

# %%
np.cov(z_output.T)
# Out:
# array([[ 0.06139277, -0.00109529, -0.00298687,  0.0555604 , -0.03440594],
#        [-0.00109529,  0.11708341, -0.07476355,  0.08695289, -0.06337568],
#        [-0.00298687, -0.07476355,  0.31348344,  0.05590957,  0.002769  ],
#        [ 0.0555604 ,  0.08695289,  0.05590957,  0.28872053, -0.11691517],
#        [-0.03440594, -0.06337568,  0.002769  , -0.11691517,  0.08875817]])

# %%
for i in range(0, latent_dim):
    plot_results(models,
                 latent_dim,
                 latent_num = i,
                 z_m_m = z_m_m ,
                 batch_size=batch_size,
                 model_name="vae_mlp")
